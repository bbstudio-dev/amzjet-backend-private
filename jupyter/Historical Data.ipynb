# %%
import os

import pymongo

import pandas as pd
import matplotlib.pyplot as plt
import bb_utils.time.utils as tu

# %%
DB_NAME = 'amz_local_search'
MONGO_URI = os.environ.get('AMZ_MONGO_URI_TEMPLATE') % (os.environ.get('AMZ_MONGO_PASSWORD'), DB_NAME)

def connect_to_db(mongo_uri):
    client = pymongo.MongoClient(mongo_uri)
    return client.get_database()

# %%
db = connect_to_db(MONGO_URI)

# %%
NUM_STATES = 50
NUM_PAGES = 3

available_results = list(db.search_pages.find({'args.query': 'carabiner clip'}))
print('Total pages: ', len(available_results))
print('Days covered: ', len(available_results) / NUM_STATES / NUM_PAGES / 2)
# Out:
# ('Total pages: ', 101539)
# ('Days covered: ', 338)

# %%
def repalce_with_none(df):
    return df.astype(object).where(df.notnull(), None)

# %%
def _get_historical_data_iter(db, user_id, query, asin):
    ranks = db.search_pages.aggregate([
        {
            '$match': {
                'args.query': query,
                'result.asins': asin,
                'args.max_pages': {
                    '$gte': 3
                }
            }
        },
        {
            '$unwind': {
                'path': '$result.asins',
                'includeArrayIndex': 'index'
            }
        },
        {
            '$match': {
                'result.asins': asin
            }
        },
        {
            '$project': {
                'asin': '$result.asins',
                'loc': '$args.ip_loc',
                'meta': '$result.meta',
                'rank': {
                    '$add': ["$result.meta.first_rank", "$index"]
                }
            }
        },
        {
            '$sort': {
                'loc.state': 1
            }
        },
    ])

    for rank_data in ranks:
        yield (rank_data['meta']['date'], rank_data['loc']['state'],
               rank_data['rank'])
    
rank_df = pd.DataFrame(_get_historical_data_iter(db, None, 'swords for kids', 'B00EAHXP1U'), columns=['date', 'state', 'rank'])
rank_df.head(3)
# Out:
# Empty DataFrame
# Columns: [date, state, rank]
# Index: []

# %%
rank_df.tail(20)
# Out:
# Empty DataFrame
# Columns: [date, state, rank]
# Index: []

# %%
pivoted_rank_df = rank_df.pivot_table(index='state',
                                      columns='date',
                                      values='rank')

pivoted_rank_df = repalce_with_none(pivoted_rank_df)

rank_chart_data = []
for state, ranks in pivoted_rank_df.iterrows():
    data = []
    for ts, rank in ranks.iteritems():
        data.append([tu.unix_seconds(ts) * 1000, rank])
    rank_chart_data.append({'name': state, 'data': data})
    
rank_chart_data
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-10-33b48fc1f5a0> in <module>()
#       1 pivoted_rank_df = rank_df.pivot_table(index='state',
#       2                                       columns='date',
# ----> 3                                       values='rank')
#       4
#       5 pivoted_rank_df = repalce_with_none(pivoted_rank_df)
#
# /Users/evgenyp/Projects/AmzJet-ZT/zt-amzjet-backend/amz-deploy/dev/.venv-dev/lib/python2.7/site-packages/pandas/core/frame.pyc in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#    5757                            aggfunc=aggfunc, fill_value=fill_value,
#    5758                            margins=margins, dropna=dropna,
# -> 5759                            margins_name=margins_name)
#    5760
#    5761     def stack(self, level=-1, dropna=True):
#
# /Users/evgenyp/Projects/AmzJet-ZT/zt-amzjet-backend/amz-deploy/dev/.venv-dev/lib/python2.7/site-packages/pandas/core/reshape/pivot.pyc in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      80
#      81     grouped = data.groupby(keys, observed=False)
# ---> 82     agged = grouped.agg(aggfunc)
#      83     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#      84         agged = agged.dropna(how='all')
#
# /Users/evgenyp/Projects/AmzJet-ZT/zt-amzjet-backend/amz-deploy/dev/.venv-dev/lib/python2.7/site-packages/pandas/core/groupby/generic.pyc in aggregate(self, arg, *args, **kwargs)
#    1313     @Appender(_shared_docs['aggregate'])
#    1314     def aggregate(self, arg, *args, **kwargs):
# -> 1315         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    1316
#    1317     agg = aggregate
#
# /Users/evgenyp/Projects/AmzJet-ZT/zt-amzjet-backend/amz-deploy/dev/.venv-dev/lib/python2.7/site-packages/pandas/core/groupby/generic.pyc in aggregate(self, arg, *args, **kwargs)
#     184
#     185         _level = kwargs.pop('_level', None)
# --> 186         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#     187         if how is None:
#     188             return result
#
# /Users/evgenyp/Projects/AmzJet-ZT/zt-amzjet-backend/amz-deploy/dev/.venv-dev/lib/python2.7/site-packages/pandas/core/base.pyc in _aggregate(self, arg, *args, **kwargs)
#     354         if isinstance(arg, compat.string_types):
#     355             return self._try_aggregate_string_function(arg, *args,
# --> 356                                                        **kwargs), None
#     357
#     358         if isinstance(arg, dict):
#
# /Users/evgenyp/Projects/AmzJet-ZT/zt-amzjet-backend/amz-deploy/dev/.venv-dev/lib/python2.7/site-packages/pandas/core/base.pyc in _try_aggregate_string_function(self, arg, *args, **kwargs)
#     310         if f is not None:
#     311             if callable(f):
# --> 312                 return f(*args, **kwargs)
#     313
#     314             # people may try to aggregate on a non-callable attribute
#
# /Users/evgenyp/Projects/AmzJet-ZT/zt-amzjet-backend/amz-deploy/dev/.venv-dev/lib/python2.7/site-packages/pandas/core/groupby/groupby.pyc in mean(self, *args, **kwargs)
#    1130         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1131         try:
# -> 1132             return self._cython_agg_general('mean', **kwargs)
#    1133         except GroupByError:
#    1134             raise
#
# /Users/evgenyp/Projects/AmzJet-ZT/zt-amzjet-backend/amz-deploy/dev/.venv-dev/lib/python2.7/site-packages/pandas/core/groupby/generic.pyc in _cython_agg_general(self, how, alt, numeric_only, min_count)
#      68                             min_count=-1):
#      69         new_items, new_blocks = self._cython_agg_blocks(
# ---> 70             how, alt=alt, numeric_only=numeric_only, min_count=min_count)
#      71         return self._wrap_agged_blocks(new_items, new_blocks)
#      72
#
# /Users/evgenyp/Projects/AmzJet-ZT/zt-amzjet-backend/amz-deploy/dev/.venv-dev/lib/python2.7/site-packages/pandas/core/groupby/generic.pyc in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#     141
#     142         if len(new_blocks) == 0:
# --> 143             raise DataError('No numeric types to aggregate')
#     144
#     145         # reset the locs in the blocks to correspond to our
#
# DataError: No numeric types to aggregate

# %%
df.pivot_table(index='date', columns='state', values='rank').plot(style='.-', figsize=(20,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-caa8f1b6e55d> in <module>()
# ----> 1 df.pivot_table(index='date', columns='state', values='rank').plot(style='.-', figsize=(20,10))
#
# NameError: name 'df' is not defined

# %%
df.pivot_table(index='date', columns='state', values='rank').plot(style='.-', figsize=(20,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-caa8f1b6e55d> in <module>()
# ----> 1 df.pivot_table(index='date', columns='state', values='rank').plot(style='.-', figsize=(20,10))
#
# NameError: name 'df' is not defined

# %%
df.pivot_table(index='date', columns='state', values='rank').resample('D').interpolate(method='cubic').plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-e2b87cea5705> in <module>()
# ----> 1 df.pivot_table(index='date', columns='state', values='rank').resample('D').interpolate(method='cubic').plot()
#
# NameError: name 'df' is not defined

# %%
df.pivot_table(index='date', columns='state', values='rank')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-b1ec1202e52a> in <module>()
# ----> 1 df.pivot_table(index='date', columns='state', values='rank')
#
# NameError: name 'df' is not defined

# %%
def repalce_with_none(df):
    return df.astype(object).where(df.notnull(), None)

df = pd.DataFrame(get_historical_data_iter(db, 'carabiner clip', 'B07P2VF8DN'), columns=['date', 'state', 'rank'])
repalce_with_none(df.pivot_table(index='state', columns='date', values='rank').reset_index()).to_dict(orient='records')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-d7fec568f27f> in <module>()
#       2     return df.astype(object).where(df.notnull(), None)
#       3
# ----> 4 df = pd.DataFrame(get_historical_data_iter(db, 'carabiner clip', 'B07P2VF8DN'), columns=['date', 'state', 'rank'])
#       5 repalce_with_none(df.pivot_table(index='state', columns='date', values='rank').reset_index()).to_dict(orient='records')
#
# NameError: name 'get_historical_data_iter' is not defined

# %%
def _get_historical_data_iter(db, query, asin):
    asins_to_match = [asin]
    ranks = db.search_pages.aggregate([
        {
            '$match': {
                'result.asins': {
                    '$in': asins_to_match
                }
            }
        },
        {
            '$unwind': {
                'path': '$result.asins',
                'includeArrayIndex': 'index'
            }
        },
        {
            '$match': {
                'result.asins': {
                    '$in': asins_to_match
                }
            }
        },
        {
            '$project': {
                'asin': '$result.asins',
                'loc': '$args.ip_loc',
                'meta': '$result.meta',
                'rank': {
                    '$add': ["$result.meta.first_rank", "$index"]
                }
            }
        },
        {
            '$sort': {
                'loc.state': 1
            }
        },
    ])

    for rank_data in ranks:
        yield (rank_data['meta']['date'], rank_data['loc']['state'], rank_data['rank'])



query = 'carabiner clip'
asin = 'B07P2VF8DN'

rank_iter = _get_historical_data_iter(db, query, asin)
rank_df = pd.DataFrame(rank_iter, columns=['date', 'state', 'rank'])

repalce_with_none(rank_df.groupby('state')['rank'].agg(['last', 'mean', 'std', 'min', 'max'])).reset_index().to_dict(orient='records')
# Out:
# [{'last': 135,
#   'max': 142,
#   'mean': 95.0,
#   'min': 6,
#   'state': u'AK',
#   'std': 53.35876586594598},
#  {'last': 128,
#   'max': 138,
#   'mean': 89.5925925925926,
#   'min': 11,
#   'state': u'AL',
#   'std': 45.613981712138745},
#  {'last': 136,
#   'max': 143,
#   'mean': 103.29166666666667,
#   'min': 6,
#   'state': u'AR',
#   'std': 44.553318489264036},
#  {'last': 143,
#   'max': 143,
#   'mean': 97.13793103448276,
#   'min': 6,
#   'state': u'AZ',
#   'std': 48.47143793582466},
#  {'last': 109,
#   'max': 140,
#   'mean': 67.39285714285714,
#   'min': 6,
#   'state': u'CA',
#   'std': 52.68181777680514},
#  {'last': 98,
#   'max': 142,
#   'mean': 101.56,
#   'min': 11,
#   'state': u'CO',
#   'std': 49.00942086306809},
#  {'last': 104,
#   'max': 143,
#   'mean': 93.38461538461539,
#   'min': 11,
#   'state': u'CT',
#   'std': 46.886310943026366},
#  {'last': 98,
#   'max': 135,
#   'mean': 83.31818181818181,
#   'min': 11,
#   'state': u'DE',
#   'std': 46.75201687896558},
#  {'last': 143,
#   'max': 143,
#   'mean': 69.42028985507247,
#   'min': 6,
#   'state': u'FL',
#   'std': 54.77209621188657},
#  {'last': 140,
#   'max': 142,
#   'mean': 107.38461538461539,
#   'min': 6,
#   'state': u'GA',
#   'std': 37.32115724733817},
#  {'last': 67,
#   'max': 142,
#   'mean': 96.84,
#   'min': 6,
#   'state': u'HI',
#   'std': 48.34397583980863},
#  {'last': 97,
#   'max': 139,
#   'mean': 87.84,
#   'min': 6,
#   'state': u'IA',
#   'std': 49.66276271010303},
#  {'last': 55,
#   'max': 144,
#   'mean': 103.34482758620689,
#   'min': 6,
#   'state': u'ID',
#   'std': 45.83999802267897},
#  {'last': 128,
#   'max': 144,
#   'mean': 77.4,
#   'min': 6,
#   'state': u'IL',
#   'std': 50.44684539717341},
#  {'last': 134,
#   'max': 142,
#   'mean': 88.47826086956522,
#   'min': 11,
#   'state': u'IN',
#   'std': 52.86076871901522},
#  {'last': 143,
#   'max': 143,
#   'mean': 81.47368421052632,
#   'min': 6,
#   'state': u'KS',
#   'std': 51.649855782365755},
#  {'last': 124,
#   'max': 143,
#   'mean': 107.11111111111111,
#   'min': 6,
#   'state': u'KY',
#   'std': 46.620986045656316},
#  {'last': 143,
#   'max': 143,
#   'mean': 100.47826086956522,
#   'min': 11,
#   'state': u'LA',
#   'std': 46.630919868120074},
#  {'last': 128,
#   'max': 144,
#   'mean': 100.53571428571429,
#   'min': 6,
#   'state': u'MA',
#   'std': 46.010048936885546},
#  {'last': 104,
#   'max': 143,
#   'mean': 98.82758620689656,
#   'min': 6,
#   'state': u'MD',
#   'std': 46.45971293613828},
#  {'last': 136,
#   'max': 141,
#   'mean': 101.24137931034483,
#   'min': 6,
#   'state': u'ME',
#   'std': 50.957724195379974},
#  {'last': 114,
#   'max': 140,
#   'mean': 95.45454545454545,
#   'min': 6,
#   'state': u'MI',
#   'std': 51.44921423133345},
#  {'last': 92,
#   'max': 144,
#   'mean': 103.89473684210526,
#   'min': 6,
#   'state': u'MN',
#   'std': 50.17402463962813},
#  {'last': 128,
#   'max': 144,
#   'mean': 101.0,
#   'min': 11,
#   'state': u'MO',
#   'std': 45.82690545037811},
#  {'last': 114,
#   'max': 142,
#   'mean': 91.21739130434783,
#   'min': 6,
#   'state': u'MS',
#   'std': 53.95027721029053},
#  {'last': 128,
#   'max': 139,
#   'mean': 104.0,
#   'min': 11,
#   'state': u'MT',
#   'std': 48.512541333831045},
#  {'last': 67,
#   'max': 141,
#   'mean': 88.68,
#   'min': 6,
#   'state': u'NC',
#   'std': 48.341424610093284},
#  {'last': 67,
#   'max': 142,
#   'mean': 98.54166666666667,
#   'min': 6,
#   'state': u'ND',
#   'std': 48.52249963691578},
#  {'last': 128,
#   'max': 140,
#   'mean': 96.13636363636364,
#   'min': 11,
#   'state': u'NE',
#   'std': 48.75038017389779},
#  {'last': 67,
#   'max': 141,
#   'mean': 97.4,
#   'min': 6,
#   'state': u'NH',
#   'std': 49.66619609435333},
#  {'last': 96,
#   'max': 142,
#   'mean': 101.4,
#   'min': 6,
#   'state': u'NJ',
#   'std': 48.39851926109585},
#  {'last': 67,
#   'max': 143,
#   'mean': 96.85185185185185,
#   'min': 6,
#   'state': u'NM',
#   'std': 50.372996202715065},
#  {'last': 138,
#   'max': 143,
#   'mean': 96.86666666666666,
#   'min': 6,
#   'state': u'NV',
#   'std': 47.4165207156916},
#  {'last': 124,
#   'max': 139,
#   'mean': 80.6,
#   'min': 6,
#   'state': u'NY',
#   'std': 52.66218057731653},
#  {'last': 128,
#   'max': 140,
#   'mean': 92.36666666666666,
#   'min': 6,
#   'state': u'OH',
#   'std': 48.01902161416463},
#  {'last': 55,
#   'max': 143,
#   'mean': 86.3913043478261,
#   'min': 6,
#   'state': u'OK',
#   'std': 49.014598131980286},
#  {'last': 115,
#   'max': 143,
#   'mean': 91.76470588235294,
#   'min': 11,
#   'state': u'OR',
#   'std': 43.51249129153285},
#  {'last': 89,
#   'max': 143,
#   'mean': 98.34782608695652,
#   'min': 6,
#   'state': u'PA',
#   'std': 51.55985814887407},
#  {'last': 112,
#   'max': 144,
#   'mean': 99.57142857142857,
#   'min': 6,
#   'state': u'RI',
#   'std': 46.19477397776877},
#  {'last': 75,
#   'max': 144,
#   'mean': 100.74285714285715,
#   'min': 6,
#   'state': u'SC',
#   'std': 48.44666130495103},
#  {'last': 123,
#   'max': 138,
#   'mean': 96.05555555555556,
#   'min': 11,
#   'state': u'SD',
#   'std': 44.72066534049703},
#  {'last': 123,
#   'max': 144,
#   'mean': 99.37931034482759,
#   'min': 6,
#   'state': u'TN',
#   'std': 49.46890350304021},
#  {'last': 84,
#   'max': 143,
#   'mean': 93.76666666666667,
#   'min': 11,
#   'state': u'TX',
#   'std': 50.19869714845495},
#  {'last': 141,
#   'max': 143,
#   'mean': 105.71428571428571,
#   'min': 6,
#   'state': u'UT',
#   'std': 41.21943311918138},
#  {'last': 102,
#   'max': 143,
#   'mean': 95.57142857142857,
#   'min': 6,
#   'state': u'VA',
#   'std': 46.64001506529565},
#  {'last': 133,
#   'max': 142,
#   'mean': 98.71428571428571,
#   'min': 6,
#   'state': u'VT',
#   'std': 49.027688969747345},
#  {'last': 46,
#   'max': 139,
#   'mean': 81.58064516129032,
#   'min': 6,
#   'state': u'WA',
#   'std': 42.49295956865355},
#  {'last': 128,
#   'max': 138,
#   'mean': 84.10526315789474,
#   'min': 11,
#   'state': u'WI',
#   'std': 51.44565064959557},
#  {'last': 67,
#   'max': 144,
#   'mean': 105.2,
#   'min': 11,
#   'state': u'WV',
#   'std': 39.95207655495057},
#  {'last': 143,
#   'max': 143,
#   'mean': 93.78260869565217,
#   'min': 11,
#   'state': u'WY',
#   'std': 52.966504442764354}]

# %%
agg_df = rank_df.groupby('state')['rank'].agg(['last', 'mean', 'std', 'min', 'max'])
agg_df.describe()

#agg_df['is_outlier'] = agg_df[]
#agg_df.describe()
# Out:
#              last        mean        std       min         max
# count   50.000000   50.000000  50.000000  50.00000   50.000000
# mean   109.740000   94.523033  48.276552   7.50000  141.860000
# std     28.301446    9.035824   3.562372   2.31455    2.040508
# min     46.000000   67.392857  37.321157   6.00000  135.000000
# 25%     93.000000   89.998792  46.500031   6.00000  141.000000
# 50%    119.000000   96.845926  48.491990   6.00000  143.000000
# 75%    131.750000  100.691071  50.428383  11.00000  143.000000
# max    143.000000  107.384615  54.772096  11.00000  144.000000

# %%
agg_df['last'].agg(['last', 'mean', 'std', 'min', 'max']).to_dict()
# Out:
# {'max': 143.0, 'mean': 109.74, 'min': 46.0, 'std': 28.301445841770946}

# %%
agg_df[agg_df['last'] == agg_df['last'].min()]
# Out:
#        last       mean       std  min  max
# state
# WA       46  81.580645  42.49296    6  139

# %%
agg_df[agg_df['last'] == agg_df['last'].max()].to_dict(orient='records')
# Out:
# [{'last': 143,
#   'max': 143,
#   'mean': 97.13793103448276,
#   'min': 6,
#   'std': 48.47143793582466},
#  {'last': 143,
#   'max': 143,
#   'mean': 69.42028985507247,
#   'min': 6,
#   'std': 54.77209621188657},
#  {'last': 143,
#   'max': 143,
#   'mean': 81.47368421052632,
#   'min': 6,
#   'std': 51.649855782365755},
#  {'last': 143,
#   'max': 143,
#   'mean': 100.47826086956522,
#   'min': 11,
#   'std': 46.630919868120074},
#  {'last': 143,
#   'max': 143,
#   'mean': 93.78260869565217,
#   'min': 11,
#   'std': 52.966504442764354}]
