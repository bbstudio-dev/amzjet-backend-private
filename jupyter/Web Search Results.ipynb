# %%
import json

import pymongo
from bson.objectid import ObjectId

import bb_utils.time.utils as tu
from amz_scrapy.spiders.amazon.search_api_spider import JsonResultsParser
from bb_utils.io.utils import open_maybe_compressed

# %%
WEB_RESULTS_FNAME = '/Users/evgenyp/Projects/AmzJet/AmzJet/__staging__/scrapy-launchers/local-local-search-web.json'

# %% [markdown]
# # Converter for web results

# %%
def norm_query(query):
    return ' '.join(query.lower().split())

def convert_search_page_data(crawler_item, product_details_map=None):
    payload = crawler_item['payload']

    req_params = payload['request']
    first_item_rank = req_params['first_item_rank']

    search_meta = payload['response']['meta']      
    products = payload['response']['products']
    
    asins = []
    sponsored_asins = []
    
    rank_details_list = []
    
    for product in products:
        asin = product['asin']
        
        if product.get('is_sponsored'):
            sponsored_asins.append(asin)
        else:
            asins.append(asin)            


        # Enable once available:
        # rank_details_list.append({
        #    'get_by':
        #    product_details.get('get_it_by_date'),
        #    'avail_msg':
        #    product_details.get('availability_message')
        # })

        # Product attributes are returned in a separate collection that
        # can be used for display purposes.
        if product_details_map is not None and asin not in product_details_map:
            product_details_map[asin] = {
                'asin': asin,
                'title': product.get('title'),
                'image_url': product.get('image'),
            }

    result_ts_utc = tu.utc_time(crawler_item['crawl_date'])
    ip_location = req_params['args']['location']
    
    search_page = {
        'args': {
            'query': req_params['args']['query'],
            'ip_loc': {
                'country': ip_location['country'],
                'state': ip_location['state']
            },
            'page_num': req_params['search_page_num'],
            'session_id': req_params['proxy_session_id'],
            'max_pages': req_params['args']['max_pages']
        },
        'result': {
            'meta': {
                'time': result_ts_utc,
                'date': tu.to_midnight(result_ts_utc),
                'first_rank': first_item_rank,
                'total_matches': search_meta['total_results'],
                'internal': search_meta['internal'],
                'parser': search_meta['parser']
            },
            'asins': asins,
            'sponsored_asins': sponsored_asins,
            'details': rank_details_list
        },
    }
    return search_page


def parse_paginated_search_results_from_file(fname, product_details_map=None):
    with open_maybe_compressed(fname) as file:
        for line in file:
            crawler_item = json.loads(line)
            search_page = convert_search_page_data(crawler_item,
                                                   product_details_map)
            yield search_page
            
product_details_map = {}
pages = list(parse_paginated_search_results_from_file(WEB_RESULTS_FNAME, product_details_map))
pages
# Out:
# [{'args': {'ip_loc': {'country': u'US', 'state': u'NY'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'e2487d0833664af397ed60993197eed8'},
#   'result': {'asins': [u'B00IOZWC2M',
#     u'B009SZXM4E',
#     u'B00T56FQAE',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B01AMJCHB8',
#     u'B00CYA4RIK',
#     u'B00JKK3MAG',
#     u'B0185PXU3K',
#     u'B07DVRNCYS',
#     u'B07J5Q6XXL',
#     u'B07QR1299Y',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B0016QX5RC',
#     u'B00VX14U6K',
#     u'B07RRYLSX9',
#     u'B01M05I0PJ',
#     u'B07PP31LC8',
#     u'B07RX7WYBM',
#     u'B079C73K48',
#     u'B0797CG5R8',
#     u'B07FWB52YG',
#     u'B000GG6EU8',
#     u'B00CDKAZY6',
#     u'B07WW5W7L2',
#     u'B00UNT5T04',
#     u'B00DS5BGAC',
#     u'B008PA091C',
#     u'B00U3SMG8S',
#     u'B07WFZY7BV',
#     u'B01D6AQQQC',
#     u'B008NC7SHU',
#     u'B07VKHZ9MJ',
#     u'B07Q6BV39V',
#     u'B00ZQ0CKJI',
#     u'B074H67KND',
#     u'B072L3KTCH',
#     u'B07B8TFKNK',
#     u'B07CNC9CLD',
#     u'B00VKHG5PG',
#     u'B07PG1XK8P',
#     u'B010CVCH70',
#     u'B07YBN49WL',
#     u'B0084H4XTK',
#     u'B07MK4B3W8',
#     u'B01LDDAI54'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'New York',
#      u'customer_zip_code': u'10004',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419174',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 60,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 36, 668426, tzinfo=<UTC>),
#     'total_matches': 722},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07BHV28DR',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B00I65AGHI',
#     u'B07R2MS7ZH',
#     u'B015QFMNZI']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'NJ'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'2bfb19b15eb34cc8ae29716b5095ff93'},
#   'result': {'asins': [u'B07CNC9CLD',
#     u'B07FJQ32BG',
#     u'B07QR1299Y',
#     u'B07J5Q6XXL',
#     u'B07DVRNCYS',
#     u'B010CVCH70',
#     u'B07YBN49WL',
#     u'B01FV7PSAI',
#     u'B01GNBMAMU',
#     u'B016IRQTSU',
#     u'B001E0T7S6',
#     u'B01CO0CZJW',
#     u'B00IBVWXZA',
#     u'B00QT5R48G',
#     u'B07CJXWG8C',
#     u'B01D242ZVW',
#     u'B07V22H8JQ',
#     u'B07R6TJQ2Y',
#     u'B07RP3GZ63',
#     u'B07T8QL8CT',
#     u'B01AVJ29MQ',
#     u'B00014IEGW',
#     u'B00ZIRMDFU',
#     u'B07XH6D52S',
#     u'B07QW44Z9F',
#     u'B00014D69C',
#     u'B008GZEVPQ',
#     u'B00RLV347C',
#     u'B07HNW7JV9',
#     u'B07Q849R9R',
#     u'B07V5K89NM',
#     u'B07RXP9534',
#     u'B07DV8MZK7',
#     u'B07RKCCG2L',
#     u'B07NZT148M',
#     u'B07GTRDKXF',
#     u'B075TLLK75',
#     u'B01GQFVZEM',
#     u'B07P5JTZM4',
#     u'B0713X4MC1',
#     u'B008PPXD56',
#     u'B00WL7P9X8',
#     u'B01B6Q1RP8',
#     u'B016G5W1IG',
#     u'B07PDNC7JT',
#     u'B07RJ1FRXN',
#     u'B07LHF672J',
#     u'B07YBXT3RQ',
#     u'B01C2AI61K',
#     u'B00U7VY0AI',
#     u'B01MRGCA6V',
#     u'B07SKKN713',
#     u'B07PJY8SBH'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'SE',
#      u'customer_city': u'STOCKHOLM',
#      u'customer_zip_code': u'100 00-200 00',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419175',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 65,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 37, 75842, tzinfo=<UTC>),
#     'total_matches': 137},
#    'sponsored_asins': [u'B07JP6HNQC',
#     u'B07DHX2HV2',
#     u'B07GNPVHTV',
#     u'B07DW39TXB',
#     u'B0798KGNSD',
#     u'B07HM7F73D',
#     u'B07946BLZ6',
#     u'B07SG66NCK',
#     u'B074CHC9D2',
#     u'B07T466NFX',
#     u'B07GJPM6T8',
#     u'B073CCHJTS']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'KY'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'd3b2c3b51a9b473bb80e4c07cd21c54f'},
#   'result': {'asins': [u'B07FJQ32BG',
#     u'B07QR1299Y',
#     u'B07J5Q6XXL',
#     u'B07DVRNCYS',
#     u'B010CVCH70',
#     u'B00IOZWC2M',
#     u'B009SZXM4E',
#     u'B00T56FQAE',
#     u'B0185PXU3K',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B01AMJCHB8',
#     u'B07P9TFHB5',
#     u'B00JKK3MAG',
#     u'B07DVRNCYS',
#     u'B07QR1299Y',
#     u'B00CYA4RIK',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B079RDR8ZD',
#     u'B07J5Q6XXL',
#     u'B00VX14U6K',
#     u'B01M05I0PJ',
#     u'B0016QX5RC',
#     u'B07FSMRY3S',
#     u'B07SNFZ9Y1',
#     u'B07RRYLSX9',
#     u'B07PP31LC8',
#     u'B01ATR95E0',
#     u'B07Q5GYQJC',
#     u'B07RX7WYBM',
#     u'B07DM5MLFV',
#     u'B07D7HRVDL',
#     u'B00VKHG5PG',
#     u'B079C73K48',
#     u'B07FWB52YG',
#     u'B07WW5W7L2',
#     u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B0797CG5R8',
#     u'B07SFLZY12',
#     u'B01HN81YL0',
#     u'B00UNT5T04',
#     u'B07RLJ2H1H',
#     u'B01D6AQQQC',
#     u'B07S2C8QKG',
#     u'B00CDKAZY6',
#     u'B008PA091C',
#     u'B000GG6EU8',
#     u'B008FL8KLC',
#     u'B0069SGC72',
#     u'B00U3SMG8S'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Louisville',
#      u'customer_zip_code': u'40272',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419175',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 65,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 37, 490503, tzinfo=<UTC>),
#     'total_matches': 723},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07BHV28DR',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B00I65AGHI',
#     u'B07R2MS7ZH',
#     u'B015QFMNZI']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'DE'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'8dfe1d504d7a43ef9174de355f18c623'},
#   'result': {'asins': [u'B00IOZWC2M',
#     u'B009SZXM4E',
#     u'B00T56FQAE',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B01AMJCHB8',
#     u'B00CYA4RIK',
#     u'B0185PXU3K',
#     u'B07DVRNCYS',
#     u'B00JKK3MAG',
#     u'B07J5Q6XXL',
#     u'B07QR1299Y',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B00VX14U6K',
#     u'B07RRYLSX9',
#     u'B07RX7WYBM',
#     u'B07FJQ32BG',
#     u'B07QR1299Y',
#     u'B07J5Q6XXL',
#     u'B07DVRNCYS',
#     u'B010CVCH70',
#     u'B0797CG5R8',
#     u'B07FWB52YG',
#     u'B000GG6EU8',
#     u'B00CDKAZY6',
#     u'B07WW5W7L2',
#     u'B00UNT5T04',
#     u'B00DS5BGAC',
#     u'B008PA091C',
#     u'B00U3SMG8S',
#     u'B01D6AQQQC',
#     u'B008NC7SHU',
#     u'B07Q6BV39V',
#     u'B07VKHZ9MJ',
#     u'B07WFZY7BV',
#     u'B074H67KND',
#     u'B072L3KTCH',
#     u'B07B8TFKNK',
#     u'B00VKHG5PG',
#     u'B0084H4XTK',
#     u'B07MK4B3W8',
#     u'B01LDDAI54',
#     u'B000J4FSVS',
#     u'B07HLRW96F',
#     u'B00NV5UTYI',
#     u'B01D6AQR7A',
#     u'B07C5GTS7D',
#     u'B074V7394F',
#     u'B07CW639YG',
#     u'B008FL8KSA',
#     u'B01M216P3O'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Newark',
#      u'customer_zip_code': u'19702',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419175',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 65,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 38, 27527, tzinfo=<UTC>),
#     'total_matches': 712},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07BHV28DR',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B00I65AGHI',
#     u'B07R2MS7ZH',
#     u'B015QFMNZI']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'MN'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'ddbcb3fa7f4541e6adbe058a58af0d2f'},
#   'result': {'asins': [u'B009SZXM4E',
#     u'B00T56FQAE',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B01AMJCHB8',
#     u'B00CYA4RIK',
#     u'B0185PXU3K',
#     u'B07DVRNCYS',
#     u'B00JKK3MAG',
#     u'B07J5Q6XXL',
#     u'B07QR1299Y',
#     u'B00DS5BG52',
#     u'B00IOZWC2M',
#     u'B00VX14U6K',
#     u'B07RRYLSX9',
#     u'B01M05I0PJ',
#     u'B079C73K48',
#     u'B07FWB52YG',
#     u'B07FJQ32BG',
#     u'B07QR1299Y',
#     u'B07J5Q6XXL',
#     u'B07DVRNCYS',
#     u'B010CVCH70',
#     u'B000GG6EU8',
#     u'B00CDKAZY6',
#     u'B00UNT5T04',
#     u'B00DS5BGAC',
#     u'B008PA091C',
#     u'B01D6AQQQC',
#     u'B008NC7SHU',
#     u'B07Q6BV39V',
#     u'B0017L7GE4',
#     u'B072L3KTCH',
#     u'B07CNC9CLD',
#     u'B0084H4XTK',
#     u'B07MK4B3W8',
#     u'B01LDDAI54',
#     u'B000J4FSVS',
#     u'B07HLRW96F',
#     u'B00NV5UTYI',
#     u'B00BPGPX1E',
#     u'B01D6AQR7A',
#     u'B07C5GTS7D',
#     u'B074V7394F',
#     u'B01NCLYPT0',
#     u'B008FL8KSA',
#     u'B07KKN1N2Y',
#     u'B00H540TA0',
#     u'B0012DZIII',
#     u'B008FL8KLC',
#     u'B000WSS3TA',
#     u'B07GZCN4FH'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Saint Paul',
#      u'customer_zip_code': u'55108',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419175',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 65,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 38, 415513, tzinfo=<UTC>),
#     'total_matches': 712},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07BHV28DR',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B015QFMNZI',
#     u'B07R2MS7ZH',
#     u'B00I65AGHI']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'CT'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'449634945309428db7b6386d1546ea14'},
#   'result': {'asins': [u'B07FJQ32BG',
#     u'B07QR1299Y',
#     u'B07J5Q6XXL',
#     u'B07DVRNCYS',
#     u'B010CVCH70',
#     u'B00IOZWC2M',
#     u'B00JKK3MAG',
#     u'B01AMJCHB8',
#     u'B07P9TFHB5',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B00T56FQAE',
#     u'B0185PXU3K',
#     u'B009SZXM4E',
#     u'B07DVRNCYS',
#     u'B07QR1299Y',
#     u'B00CYA4RIK',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B079RDR8ZD',
#     u'B07J5Q6XXL',
#     u'B00VX14U6K',
#     u'B01M05I0PJ',
#     u'B0016QX5RC',
#     u'B07FSMRY3S',
#     u'B07SNFZ9Y1',
#     u'B07RRYLSX9',
#     u'B07PP31LC8',
#     u'B01ATR95E0',
#     u'B07Q5GYQJC',
#     u'B07RX7WYBM',
#     u'B07DM5MLFV',
#     u'B07D7HRVDL',
#     u'B00VKHG5PG',
#     u'B079C73K48',
#     u'B07FWB52YG',
#     u'B07WW5W7L2',
#     u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B0797CG5R8',
#     u'B07SFLZY12',
#     u'B01HN81YL0',
#     u'B00UNT5T04',
#     u'B07RLJ2H1H',
#     u'B01D6AQQQC',
#     u'B07S2C8QKG',
#     u'B00CDKAZY6',
#     u'B008PA091C',
#     u'B000GG6EU8',
#     u'B008FL8KLC',
#     u'B0069SGC72',
#     u'B00U3SMG8S'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Coventry',
#      u'customer_zip_code': u'06238',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419175',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 65,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 38, 856133, tzinfo=<UTC>),
#     'total_matches': 712},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07BHV28DR',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B015QFMNZI',
#     u'B07R2MS7ZH',
#     u'B00I65AGHI']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'SC'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'6e154d4ed73543b8a1019da14bc3ab52'},
#   'result': {'asins': [u'B07FJQ32BG',
#     u'B07QR1299Y',
#     u'B07J5Q6XXL',
#     u'B07DVRNCYS',
#     u'B010CVCH70',
#     u'B00IOZWC2M',
#     u'B00JKK3MAG',
#     u'B009SZXM4E',
#     u'B01AMJCHB8',
#     u'B00T56FQAE',
#     u'B07P9TFHB5',
#     u'B0185PXU3K',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B07DVRNCYS',
#     u'B07QR1299Y',
#     u'B00CYA4RIK',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B079RDR8ZD',
#     u'B07J5Q6XXL',
#     u'B00VX14U6K',
#     u'B01M05I0PJ',
#     u'B0016QX5RC',
#     u'B07FSMRY3S',
#     u'B07SNFZ9Y1',
#     u'B07RRYLSX9',
#     u'B07PP31LC8',
#     u'B01ATR95E0',
#     u'B07Q5GYQJC',
#     u'B07RX7WYBM',
#     u'B07DM5MLFV',
#     u'B07D7HRVDL',
#     u'B00VKHG5PG',
#     u'B079C73K48',
#     u'B07FWB52YG',
#     u'B07WW5W7L2',
#     u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B0797CG5R8',
#     u'B07SFLZY12',
#     u'B01HN81YL0',
#     u'B00UNT5T04',
#     u'B07RLJ2H1H',
#     u'B01D6AQQQC',
#     u'B07S2C8QKG',
#     u'B00CDKAZY6',
#     u'B008PA091C',
#     u'B000GG6EU8',
#     u'B008FL8KLC',
#     u'B0069SGC72',
#     u'B00U3SMG8S'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Gilbert',
#      u'customer_zip_code': u'29054',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419176',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 65,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 39, 309976, tzinfo=<UTC>),
#     'total_matches': 712},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07BHV28DR',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B015QFMNZI',
#     u'B07R2MS7ZH',
#     u'B00I65AGHI']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'NV'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'40efe21cd4344f2b99d992ced3bed66a'},
#   'result': {'asins': [u'B00IOZWC2M',
#     u'B009SZXM4E',
#     u'B00T56FQAE',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B01AMJCHB8',
#     u'B00CYA4RIK',
#     u'B00JKK3MAG',
#     u'B0185PXU3K',
#     u'B07DVRNCYS',
#     u'B07J5Q6XXL',
#     u'B07QR1299Y',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B0016QX5RC',
#     u'B00VX14U6K',
#     u'B07RRYLSX9',
#     u'B01M05I0PJ',
#     u'B07P9TFHB5',
#     u'B07PP31LC8',
#     u'B07RX7WYBM',
#     u'B079C73K48',
#     u'B0797CG5R8',
#     u'B07FWB52YG',
#     u'B07MK4B3W8',
#     u'B000GG6EU8',
#     u'B00CDKAZY6',
#     u'B07WW5W7L2',
#     u'B00UNT5T04',
#     u'B00DS5BGAC',
#     u'B008PA091C',
#     u'B00U3SMG8S',
#     u'B07WFZY7BV',
#     u'B01D6AQQQC',
#     u'B008NC7SHU',
#     u'B07VKHZ9MJ',
#     u'B079RDR8ZD',
#     u'B07Q6BV39V',
#     u'B01HN81YL0',
#     u'B00ZQ0CKJI',
#     u'B07M68BF8R',
#     u'B074H67KND',
#     u'B072L3KTCH',
#     u'B07CNC9CLD',
#     u'B00VKHG5PG',
#     u'B07PG1XK8P',
#     u'B07Q5GYQJC'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Las Vegas',
#      u'customer_zip_code': u'89119',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419176',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 60,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 39, 649339, tzinfo=<UTC>),
#     'total_matches': 11945},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07BHV28DR',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B00I65AGHI',
#     u'B07R2MS7ZH',
#     u'B015QFMNZI']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'NC'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'f97cd13d968c44c682b7e32b6e23fb32'},
#   'result': {'asins': [u'B00IOZWC2M',
#     u'B00JKK3MAG',
#     u'B01AMJCHB8',
#     u'B07P9TFHB5',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B00T56FQAE',
#     u'B0185PXU3K',
#     u'B009SZXM4E',
#     u'B07DVRNCYS',
#     u'B07QR1299Y',
#     u'B00CYA4RIK',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B079RDR8ZD',
#     u'B07J5Q6XXL',
#     u'B00VX14U6K',
#     u'B01M05I0PJ',
#     u'B07FJQ32BG',
#     u'B07QR1299Y',
#     u'B07J5Q6XXL',
#     u'B07DVRNCYS',
#     u'B010CVCH70',
#     u'B0016QX5RC',
#     u'B07FSMRY3S',
#     u'B07SNFZ9Y1',
#     u'B07RRYLSX9',
#     u'B07PP31LC8',
#     u'B01ATR95E0',
#     u'B07Q5GYQJC',
#     u'B07RX7WYBM',
#     u'B07DM5MLFV',
#     u'B07D7HRVDL',
#     u'B00VKHG5PG',
#     u'B079C73K48',
#     u'B07FWB52YG',
#     u'B07WW5W7L2',
#     u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B0797CG5R8',
#     u'B07SFLZY12',
#     u'B01HN81YL0',
#     u'B00UNT5T04',
#     u'B07RLJ2H1H',
#     u'B01D6AQQQC',
#     u'B07S2C8QKG',
#     u'B00CDKAZY6',
#     u'B008PA091C',
#     u'B000GG6EU8',
#     u'B008FL8KLC',
#     u'B0069SGC72',
#     u'B00U3SMG8S'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Reidsville',
#      u'customer_zip_code': u'27320',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419175',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 65,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 39, 966265, tzinfo=<UTC>),
#     'total_matches': 712},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B07Y5PCHH7',
#     u'B00T56FQAE',
#     u'B07M68BF8R',
#     u'B07QR1299Y',
#     u'B07DVRNCYS',
#     u'B015QFMNZI',
#     u'B07BHV28DR',
#     u'B07JP6HNQC',
#     u'B07MF44P9Z',
#     u'B01AMJCHB8',
#     u'B07RX7WYBM']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'WY'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'1eaca5f32bd742539f5fe525ac5db0f9'},
#   'result': {'asins': [u'B07FJQ32BG',
#     u'B07QR1299Y',
#     u'B07J5Q6XXL',
#     u'B07DVRNCYS',
#     u'B010CVCH70',
#     u'B00IOZWC2M',
#     u'B009SZXM4E',
#     u'B00JKK3MAG',
#     u'B00T56FQAE',
#     u'B01AMJCHB8',
#     u'B0185PXU3K',
#     u'B07P9TFHB5',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B07DVRNCYS',
#     u'B07QR1299Y',
#     u'B00CYA4RIK',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B079RDR8ZD',
#     u'B07J5Q6XXL',
#     u'B00VX14U6K',
#     u'B01M05I0PJ',
#     u'B0016QX5RC',
#     u'B07FSMRY3S',
#     u'B07SNFZ9Y1',
#     u'B07RRYLSX9',
#     u'B07PP31LC8',
#     u'B01ATR95E0',
#     u'B07Q5GYQJC',
#     u'B07RX7WYBM',
#     u'B07DM5MLFV',
#     u'B07D7HRVDL',
#     u'B00VKHG5PG',
#     u'B079C73K48',
#     u'B07FWB52YG',
#     u'B07WW5W7L2',
#     u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B0797CG5R8',
#     u'B07SFLZY12',
#     u'B01HN81YL0',
#     u'B00UNT5T04',
#     u'B07RLJ2H1H',
#     u'B01D6AQQQC',
#     u'B07S2C8QKG',
#     u'B00CDKAZY6',
#     u'B008PA091C',
#     u'B000GG6EU8',
#     u'B008FL8KLC',
#     u'B0069SGC72',
#     u'B00U3SMG8S'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Cheyenne',
#      u'customer_zip_code': u'82001',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419176',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 65,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 40, 297539, tzinfo=<UTC>),
#     'total_matches': 8726},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B00I65AGHI',
#     u'B07R2MS7ZH',
#     u'B015QFMNZI',
#     u'B07VPD46DY']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'AL'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'a021198b646f4b85997ee7ec090163e9'},
#   'result': {'asins': [u'B07FJQ32BG',
#     u'B07QR1299Y',
#     u'B07J5Q6XXL',
#     u'B07DVRNCYS',
#     u'B010CVCH70',
#     u'B00IOZWC2M',
#     u'B009SZXM4E',
#     u'B00JKK3MAG',
#     u'B00T56FQAE',
#     u'B01AMJCHB8',
#     u'B0185PXU3K',
#     u'B07P9TFHB5',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B07DVRNCYS',
#     u'B07QR1299Y',
#     u'B00CYA4RIK',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B079RDR8ZD',
#     u'B07J5Q6XXL',
#     u'B00VX14U6K',
#     u'B01M05I0PJ',
#     u'B0016QX5RC',
#     u'B07FSMRY3S',
#     u'B07SNFZ9Y1',
#     u'B07RRYLSX9',
#     u'B07PP31LC8',
#     u'B01ATR95E0',
#     u'B07Q5GYQJC',
#     u'B07RX7WYBM',
#     u'B07DM5MLFV',
#     u'B07D7HRVDL',
#     u'B00VKHG5PG',
#     u'B079C73K48',
#     u'B07FWB52YG',
#     u'B07WW5W7L2',
#     u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B0797CG5R8',
#     u'B07SFLZY12',
#     u'B01HN81YL0',
#     u'B00UNT5T04',
#     u'B07RLJ2H1H',
#     u'B01D6AQQQC',
#     u'B07S2C8QKG',
#     u'B00CDKAZY6',
#     u'B008PA091C',
#     u'B000GG6EU8',
#     u'B008FL8KLC',
#     u'B0069SGC72',
#     u'B00U3SMG8S'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Tuscaloosa',
#      u'customer_zip_code': u'35401',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419176',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 65,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 40, 622249, tzinfo=<UTC>),
#     'total_matches': 712},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07BHV28DR',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B00I65AGHI',
#     u'B07R2MS7ZH',
#     u'B015QFMNZI']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'UT'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'9c9cfb93529e4ef19c8bde4be297badc'},
#   'result': {'asins': [u'B00IOZWC2M',
#     u'B00JKK3MAG',
#     u'B009SZXM4E',
#     u'B01AMJCHB8',
#     u'B00T56FQAE',
#     u'B07P9TFHB5',
#     u'B0185PXU3K',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B07DVRNCYS',
#     u'B07QR1299Y',
#     u'B07FJQ32BG',
#     u'B07QR1299Y',
#     u'B07J5Q6XXL',
#     u'B07DVRNCYS',
#     u'B010CVCH70',
#     u'B00CYA4RIK',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B079RDR8ZD',
#     u'B07J5Q6XXL',
#     u'B00VX14U6K',
#     u'B01M05I0PJ',
#     u'B0016QX5RC',
#     u'B07FSMRY3S',
#     u'B07SNFZ9Y1',
#     u'B07RRYLSX9',
#     u'B07PP31LC8',
#     u'B01ATR95E0',
#     u'B07Q5GYQJC',
#     u'B07RX7WYBM',
#     u'B07DM5MLFV',
#     u'B07D7HRVDL',
#     u'B00VKHG5PG',
#     u'B079C73K48',
#     u'B07FWB52YG',
#     u'B07WW5W7L2',
#     u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B0797CG5R8',
#     u'B07SFLZY12',
#     u'B01HN81YL0',
#     u'B00UNT5T04',
#     u'B07RLJ2H1H',
#     u'B01D6AQQQC',
#     u'B07S2C8QKG',
#     u'B00CDKAZY6',
#     u'B008PA091C',
#     u'B000GG6EU8',
#     u'B008FL8KLC',
#     u'B0069SGC72',
#     u'B00U3SMG8S'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Lehi',
#      u'customer_zip_code': u'84043',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419176',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 65,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 41, 105430, tzinfo=<UTC>),
#     'total_matches': 8709},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B07R2MS7ZH',
#     u'B00I65AGHI',
#     u'B07VPD46DY',
#     u'B07DVRNCYS']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'MD'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'3d366cacc1ef47b3a5ec466cadc24ea3'},
#   'result': {'asins': [u'B00IOZWC2M',
#     u'B009SZXM4E',
#     u'B00T56FQAE',
#     u'B0185PXU3K',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B01AMJCHB8',
#     u'B07P9TFHB5',
#     u'B00JKK3MAG',
#     u'B07DVRNCYS',
#     u'B07QR1299Y',
#     u'B00CYA4RIK',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B079RDR8ZD',
#     u'B07J5Q6XXL',
#     u'B00VX14U6K',
#     u'B01M05I0PJ',
#     u'B0016QX5RC',
#     u'B07FSMRY3S',
#     u'B07SNFZ9Y1',
#     u'B07RRYLSX9',
#     u'B07PP31LC8',
#     u'B01ATR95E0',
#     u'B07Q5GYQJC',
#     u'B07RX7WYBM',
#     u'B07DM5MLFV',
#     u'B07D7HRVDL',
#     u'B00VKHG5PG',
#     u'B079C73K48',
#     u'B07FWB52YG',
#     u'B07WW5W7L2',
#     u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B0797CG5R8',
#     u'B07SFLZY12',
#     u'B01HN81YL0',
#     u'B00UNT5T04',
#     u'B07RLJ2H1H',
#     u'B01D6AQQQC',
#     u'B07S2C8QKG',
#     u'B00CDKAZY6',
#     u'B008PA091C',
#     u'B000GG6EU8',
#     u'B008FL8KLC',
#     u'B0069SGC72',
#     u'B00U3SMG8S'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Clinton',
#      u'customer_zip_code': u'20735',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419176',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 60,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 41, 445166, tzinfo=<UTC>),
#     'total_matches': 723},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07BHV28DR',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B07R2MS7ZH',
#     u'B00I65AGHI',
#     u'B07VPD46DY']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'IL'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'09388ec0120247afb93994dd100ba63c'},
#   'result': {'asins': [u'B00IOZWC2M',
#     u'B009SZXM4E',
#     u'B00T56FQAE',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B01AMJCHB8',
#     u'B00CYA4RIK',
#     u'B00JKK3MAG',
#     u'B0185PXU3K',
#     u'B07DVRNCYS',
#     u'B07J5Q6XXL',
#     u'B00DS5BG52',
#     u'B00VX14U6K',
#     u'B07RRYLSX9',
#     u'B01M05I0PJ',
#     u'B07PP31LC8',
#     u'B07RX7WYBM',
#     u'B079C73K48',
#     u'B07FWB52YG',
#     u'B07FJQ32BG',
#     u'B07QR1299Y',
#     u'B07J5Q6XXL',
#     u'B07DVRNCYS',
#     u'B010CVCH70',
#     u'B000GG6EU8',
#     u'B00CDKAZY6',
#     u'B07WW5W7L2',
#     u'B00UNT5T04',
#     u'B00DS5BGAC',
#     u'B008PA091C',
#     u'B0017L7GE4',
#     u'B00U3SMG8S',
#     u'B07WFZY7BV',
#     u'B01D6AQQQC',
#     u'B008NC7SHU',
#     u'B07VKHZ9MJ',
#     u'B07Q6BV39V',
#     u'B00ZQ0CKJI',
#     u'B074H67KND',
#     u'B07B8TFKNK',
#     u'B07CNC9CLD',
#     u'B00VKHG5PG',
#     u'B07PG1XK8P',
#     u'B07MK4B3W8',
#     u'B01LDDAI54',
#     u'B000J4FSVS',
#     u'B07HLRW96F',
#     u'B00NV5UTYI',
#     u'B00T5KHWX4',
#     u'B07C5GTS7D',
#     u'B00BPGPX1E',
#     u'B01D6AQR7A'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Wheeling',
#      u'customer_zip_code': u'60090',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419176',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 65,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 41, 789783, tzinfo=<UTC>),
#     'total_matches': 713},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07BHV28DR',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B00I65AGHI',
#     u'B07R2MS7ZH',
#     u'B015QFMNZI']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'PA'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'7562cc895812487fbb1febd5bb742228'},
#   'result': {'asins': [u'B07FJQ32BG',
#     u'B07QR1299Y',
#     u'B07J5Q6XXL',
#     u'B07DVRNCYS',
#     u'B010CVCH70',
#     u'B00IOZWC2M',
#     u'B00JKK3MAG',
#     u'B01AMJCHB8',
#     u'B07P9TFHB5',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B00T56FQAE',
#     u'B0185PXU3K',
#     u'B009SZXM4E',
#     u'B07DVRNCYS',
#     u'B07QR1299Y',
#     u'B00CYA4RIK',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B079RDR8ZD',
#     u'B07J5Q6XXL',
#     u'B00VX14U6K',
#     u'B01M05I0PJ',
#     u'B0016QX5RC',
#     u'B07FSMRY3S',
#     u'B07SNFZ9Y1',
#     u'B07RRYLSX9',
#     u'B07PP31LC8',
#     u'B01ATR95E0',
#     u'B07Q5GYQJC',
#     u'B07RX7WYBM',
#     u'B07DM5MLFV',
#     u'B07D7HRVDL',
#     u'B00VKHG5PG',
#     u'B079C73K48',
#     u'B07FWB52YG',
#     u'B07WW5W7L2',
#     u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B0797CG5R8',
#     u'B07SFLZY12',
#     u'B01HN81YL0',
#     u'B00UNT5T04',
#     u'B07RLJ2H1H',
#     u'B01D6AQQQC',
#     u'B07S2C8QKG',
#     u'B00CDKAZY6',
#     u'B008PA091C',
#     u'B000GG6EU8',
#     u'B008FL8KLC',
#     u'B0069SGC72',
#     u'B00U3SMG8S'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Bryn Mawr',
#      u'customer_zip_code': u'19010',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419176',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 65,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 42, 103694, tzinfo=<UTC>),
#     'total_matches': 8131},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B00I65AGHI',
#     u'B07R2MS7ZH',
#     u'B015QFMNZI',
#     u'B07VPD46DY']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'IN'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'86059fa4a0874d99aa8a1e5c8b5c295e'},
#   'result': {'asins': [u'B00IOZWC2M',
#     u'B009SZXM4E',
#     u'B00JKK3MAG',
#     u'B00T56FQAE',
#     u'B01AMJCHB8',
#     u'B0185PXU3K',
#     u'B07P9TFHB5',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B07DVRNCYS',
#     u'B07QR1299Y',
#     u'B00CYA4RIK',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B079RDR8ZD',
#     u'B07J5Q6XXL',
#     u'B00VX14U6K',
#     u'B01M05I0PJ',
#     u'B0016QX5RC',
#     u'B07FSMRY3S',
#     u'B07SNFZ9Y1',
#     u'B07RRYLSX9',
#     u'B07PP31LC8',
#     u'B01ATR95E0',
#     u'B07Q5GYQJC',
#     u'B07RX7WYBM',
#     u'B07DM5MLFV',
#     u'B07D7HRVDL',
#     u'B00VKHG5PG',
#     u'B079C73K48',
#     u'B07FWB52YG',
#     u'B07WW5W7L2',
#     u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B0797CG5R8',
#     u'B07SFLZY12',
#     u'B01HN81YL0',
#     u'B00UNT5T04',
#     u'B07RLJ2H1H',
#     u'B01D6AQQQC',
#     u'B07S2C8QKG',
#     u'B00CDKAZY6',
#     u'B008PA091C',
#     u'B000GG6EU8',
#     u'B008FL8KLC',
#     u'B0069SGC72',
#     u'B00U3SMG8S'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Indianapolis',
#      u'customer_zip_code': u'46205',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419176',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 60,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 42, 471167, tzinfo=<UTC>),
#     'total_matches': 713},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07BHV28DR',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B00I65AGHI',
#     u'B07R2MS7ZH',
#     u'B015QFMNZI']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'NM'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'6927a1b0972d406bbc880da0332fee79'},
#   'result': {'asins': [u'B00IOZWC2M',
#     u'B00JKK3MAG',
#     u'B01AMJCHB8',
#     u'B07P9TFHB5',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B00T56FQAE',
#     u'B0185PXU3K',
#     u'B009SZXM4E',
#     u'B07DVRNCYS',
#     u'B07QR1299Y',
#     u'B00CYA4RIK',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B079RDR8ZD',
#     u'B07J5Q6XXL',
#     u'B00VX14U6K',
#     u'B01M05I0PJ',
#     u'B0016QX5RC',
#     u'B07FSMRY3S',
#     u'B07SNFZ9Y1',
#     u'B07RRYLSX9',
#     u'B07PP31LC8',
#     u'B01ATR95E0',
#     u'B07Q5GYQJC',
#     u'B07RX7WYBM',
#     u'B07DM5MLFV',
#     u'B07D7HRVDL',
#     u'B00VKHG5PG',
#     u'B079C73K48',
#     u'B07FWB52YG',
#     u'B07WW5W7L2',
#     u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B0797CG5R8',
#     u'B07SFLZY12',
#     u'B01HN81YL0',
#     u'B00UNT5T04',
#     u'B07RLJ2H1H',
#     u'B01D6AQQQC',
#     u'B07S2C8QKG',
#     u'B00CDKAZY6',
#     u'B008PA091C',
#     u'B000GG6EU8',
#     u'B008FL8KLC',
#     u'B0069SGC72',
#     u'B00U3SMG8S'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Albuquerque',
#      u'customer_zip_code': u'87112',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419176',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 60,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 42, 800908, tzinfo=<UTC>),
#     'total_matches': 8134},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07BHV28DR',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B07R2MS7ZH',
#     u'B00I65AGHI',
#     u'B07VPD46DY']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'CO'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'b34b58034a5448bfa5fa8e44c3f2c0bb'},
#   'result': {'asins': [u'B00IOZWC2M',
#     u'B00JKK3MAG',
#     u'B009SZXM4E',
#     u'B01AMJCHB8',
#     u'B00T56FQAE',
#     u'B07P9TFHB5',
#     u'B0185PXU3K',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B07DVRNCYS',
#     u'B07QR1299Y',
#     u'B00CYA4RIK',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B079RDR8ZD',
#     u'B07J5Q6XXL',
#     u'B00VX14U6K',
#     u'B01M05I0PJ',
#     u'B0016QX5RC',
#     u'B07FSMRY3S',
#     u'B07SNFZ9Y1',
#     u'B07RRYLSX9',
#     u'B07PP31LC8',
#     u'B01ATR95E0',
#     u'B07Q5GYQJC',
#     u'B07RX7WYBM',
#     u'B07DM5MLFV',
#     u'B07D7HRVDL',
#     u'B00VKHG5PG',
#     u'B079C73K48',
#     u'B07FWB52YG',
#     u'B07WW5W7L2',
#     u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B0797CG5R8',
#     u'B07SFLZY12',
#     u'B01HN81YL0',
#     u'B00UNT5T04',
#     u'B07RLJ2H1H',
#     u'B01D6AQQQC',
#     u'B07S2C8QKG',
#     u'B00CDKAZY6',
#     u'B008PA091C',
#     u'B000GG6EU8',
#     u'B008FL8KLC',
#     u'B0069SGC72',
#     u'B00U3SMG8S'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Fort Collins',
#      u'customer_zip_code': u'80526',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419176',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 60,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 43, 126050, tzinfo=<UTC>),
#     'total_matches': 723},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07BHV28DR',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B00I65AGHI',
#     u'B07R2MS7ZH',
#     u'B015QFMNZI']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'FL'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'49dc0fed32774b7f9abb0e79018f9488'},
#   'result': {'asins': [u'B00IOZWC2M',
#     u'B00JKK3MAG',
#     u'B009SZXM4E',
#     u'B01AMJCHB8',
#     u'B00T56FQAE',
#     u'B07P9TFHB5',
#     u'B0185PXU3K',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B07DVRNCYS',
#     u'B07QR1299Y',
#     u'B00CYA4RIK',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B079RDR8ZD',
#     u'B07J5Q6XXL',
#     u'B00VX14U6K',
#     u'B01M05I0PJ',
#     u'B0016QX5RC',
#     u'B07FSMRY3S',
#     u'B07SNFZ9Y1',
#     u'B07RRYLSX9',
#     u'B07PP31LC8',
#     u'B01ATR95E0',
#     u'B07Q5GYQJC',
#     u'B07RX7WYBM',
#     u'B07DM5MLFV',
#     u'B07D7HRVDL',
#     u'B00VKHG5PG',
#     u'B079C73K48',
#     u'B07FWB52YG',
#     u'B07WW5W7L2',
#     u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B0797CG5R8',
#     u'B07SFLZY12',
#     u'B01HN81YL0',
#     u'B00UNT5T04',
#     u'B07RLJ2H1H',
#     u'B01D6AQQQC',
#     u'B07S2C8QKG',
#     u'B00CDKAZY6',
#     u'B008PA091C',
#     u'B000GG6EU8',
#     u'B008FL8KLC',
#     u'B0069SGC72',
#     u'B00U3SMG8S'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Saint Cloud',
#      u'customer_zip_code': u'34769',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419176',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 60,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 43, 477990, tzinfo=<UTC>),
#     'total_matches': 11956},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07BHV28DR',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B00I65AGHI',
#     u'B07R2MS7ZH',
#     u'B015QFMNZI']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'VT'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'e70f6a6e758148059978f4da1b8733f3'},
#   'result': {'asins': [u'B00IOZWC2M',
#     u'B00JKK3MAG',
#     u'B01AMJCHB8',
#     u'B07P9TFHB5',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B00T56FQAE',
#     u'B0185PXU3K',
#     u'B009SZXM4E',
#     u'B07DVRNCYS',
#     u'B07QR1299Y',
#     u'B00CYA4RIK',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B079RDR8ZD',
#     u'B07J5Q6XXL',
#     u'B00VX14U6K',
#     u'B01M05I0PJ',
#     u'B0016QX5RC',
#     u'B07FSMRY3S',
#     u'B07SNFZ9Y1',
#     u'B07RRYLSX9',
#     u'B07PP31LC8',
#     u'B01ATR95E0',
#     u'B07Q5GYQJC',
#     u'B07RX7WYBM',
#     u'B07DM5MLFV',
#     u'B07D7HRVDL',
#     u'B00VKHG5PG',
#     u'B079C73K48',
#     u'B07FWB52YG',
#     u'B07WW5W7L2',
#     u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B0797CG5R8',
#     u'B07SFLZY12',
#     u'B01HN81YL0',
#     u'B00UNT5T04',
#     u'B07RLJ2H1H',
#     u'B01D6AQQQC',
#     u'B07S2C8QKG',
#     u'B00CDKAZY6',
#     u'B008PA091C',
#     u'B000GG6EU8',
#     u'B008FL8KLC',
#     u'B0069SGC72',
#     u'B00U3SMG8S'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Williston',
#      u'customer_zip_code': u'05495',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419176',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 60,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 43, 856777, tzinfo=<UTC>),
#     'total_matches': 8113},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07BHV28DR',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B00I65AGHI',
#     u'B07R2MS7ZH',
#     u'B015QFMNZI']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'CA'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'40115489583542808e1afb72ae80efc5'},
#   'result': {'asins': [u'B00IOZWC2M',
#     u'B00T56FQAE',
#     u'B00OJOFX2S',
#     u'B01AMJCHB8',
#     u'B00JKK3MAG',
#     u'B0185PXU3K',
#     u'B07DVRNCYS',
#     u'B0719HYML3',
#     u'B00VX14U6K',
#     u'B07RRYLSX9',
#     u'B0797CG5R8',
#     u'B00CYA4RIK',
#     u'B000GG6EU8',
#     u'B07WW5W7L2',
#     u'B00DS5BGAC',
#     u'B07J5Q6XXL',
#     u'B07QR1299Y',
#     u'B00U3SMG8S',
#     u'B01D6AQQQC',
#     u'B07FJQ32BG',
#     u'B07QR1299Y',
#     u'B07J5Q6XXL',
#     u'B07DVRNCYS',
#     u'B010CVCH70',
#     u'B008NC7SHU',
#     u'B079RDR8ZD',
#     u'B00DS5BG52',
#     u'B009SZXM4E',
#     u'B0016QX5RC',
#     u'B01M05I0PJ',
#     u'B07PP31LC8',
#     u'B07RX7WYBM',
#     u'B000J4FSVS',
#     u'B074V7394F',
#     u'B07CW639YG',
#     u'B008FL8KSA',
#     u'B079C73K48',
#     u'B01G4SQMU8',
#     u'B07MK4B3W8',
#     u'B00CDKAZY6',
#     u'B008FL8KLC',
#     u'B07SFLZY12',
#     u'B00UNT5T04',
#     u'B0012DZIII',
#     u'B015QFMNZI',
#     u'B07B43JXZ6',
#     u'B00EODALHQ',
#     u'B000WSS3TA',
#     u'B008PA091C',
#     u'B07WFZY7BV',
#     u'B07Q6BV39V',
#     u'B07FJQ32BG',
#     u'B00028OF06'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Los Angeles',
#      u'customer_zip_code': u'90063',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419176',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 65,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 44, 218572, tzinfo=<UTC>),
#     'total_matches': 11962},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07BHV28DR',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B00I65AGHI',
#     u'B07R2MS7ZH',
#     u'B015QFMNZI']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'AR'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'1c02e2d6afcb4099944e700f557d39e8'},
#   'result': {'asins': [u'B00IOZWC2M',
#     u'B00JKK3MAG',
#     u'B009SZXM4E',
#     u'B01AMJCHB8',
#     u'B00T56FQAE',
#     u'B07P9TFHB5',
#     u'B0185PXU3K',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B07DVRNCYS',
#     u'B07QR1299Y',
#     u'B00CYA4RIK',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B079RDR8ZD',
#     u'B07J5Q6XXL',
#     u'B00VX14U6K',
#     u'B01M05I0PJ',
#     u'B07FJQ32BG',
#     u'B07QR1299Y',
#     u'B07J5Q6XXL',
#     u'B07DVRNCYS',
#     u'B010CVCH70',
#     u'B0016QX5RC',
#     u'B07FSMRY3S',
#     u'B07SNFZ9Y1',
#     u'B07RRYLSX9',
#     u'B07PP31LC8',
#     u'B01ATR95E0',
#     u'B07Q5GYQJC',
#     u'B07RX7WYBM',
#     u'B07DM5MLFV',
#     u'B07D7HRVDL',
#     u'B00VKHG5PG',
#     u'B079C73K48',
#     u'B07FWB52YG',
#     u'B07WW5W7L2',
#     u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B0797CG5R8',
#     u'B07SFLZY12',
#     u'B01HN81YL0',
#     u'B00UNT5T04',
#     u'B07RLJ2H1H',
#     u'B01D6AQQQC',
#     u'B07S2C8QKG',
#     u'B00CDKAZY6',
#     u'B008PA091C',
#     u'B000GG6EU8',
#     u'B008FL8KLC',
#     u'B0069SGC72',
#     u'B00U3SMG8S'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Amity',
#      u'customer_zip_code': u'71921',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419176',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 65,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 44, 671797, tzinfo=<UTC>),
#     'total_matches': 11358},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B015QFMNZI',
#     u'B07R2MS7ZH',
#     u'B00I65AGHI',
#     u'B07DVRNCYS']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'ND'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'59c5f1593fa04f8abe90e8eb03196a41'},
#   'result': {'asins': [u'B00IOZWC2M',
#     u'B009SZXM4E',
#     u'B00T56FQAE',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B01AMJCHB8',
#     u'B00CYA4RIK',
#     u'B00JKK3MAG',
#     u'B0185PXU3K',
#     u'B07DVRNCYS',
#     u'B07J5Q6XXL',
#     u'B07QR1299Y',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B0016QX5RC',
#     u'B00VX14U6K',
#     u'B07RRYLSX9',
#     u'B01M05I0PJ',
#     u'B07PP31LC8',
#     u'B07RX7WYBM',
#     u'B079C73K48',
#     u'B07FJQ32BG',
#     u'B07QR1299Y',
#     u'B07J5Q6XXL',
#     u'B07DVRNCYS',
#     u'B010CVCH70',
#     u'B0797CG5R8',
#     u'B07FWB52YG',
#     u'B000GG6EU8',
#     u'B00CDKAZY6',
#     u'B07WW5W7L2',
#     u'B00UNT5T04',
#     u'B00DS5BGAC',
#     u'B008PA091C',
#     u'B00U3SMG8S',
#     u'B07WFZY7BV',
#     u'B01D6AQQQC',
#     u'B008NC7SHU',
#     u'B07VKHZ9MJ',
#     u'B07Q6BV39V',
#     u'B00ZQ0CKJI',
#     u'B074H67KND',
#     u'B072L3KTCH',
#     u'B07B8TFKNK',
#     u'B07CNC9CLD',
#     u'B00VKHG5PG',
#     u'B07PG1XK8P',
#     u'B010CVCH70',
#     u'B07YBN49WL',
#     u'B0084H4XTK',
#     u'B07MK4B3W8',
#     u'B01LDDAI54'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Minot',
#      u'customer_zip_code': u'58701',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419176',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 65,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 19, 44, 978209, tzinfo=<UTC>),
#     'total_matches': 712},
#    'sponsored_asins': [u'B019ZZB3O2',
#     u'B00T56FQAE',
#     u'B00IOZWC2M',
#     u'B01AMJCHB8',
#     u'B07BHV28DR',
#     u'B07MF44P9Z',
#     u'B07Y5PCHH7',
#     u'B07QR1299Y',
#     u'B07M68BF8R',
#     u'B00I65AGHI',
#     u'B07R2MS7ZH',
#     u'B015QFMNZI']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'AZ'},
#    'max_pages': 3,
#    'page_num': 1,
#    'query': u'biotin',
#    'session_id': u'f16c97ea2e3c4663b28d96d367f18455'},
#   'result': {'asins': [u'B00IOZWC2M',
#     u'B009SZXM4E',
#     u'B00T56FQAE',
#     u'B0185PXU3K',
#     u'B0719HYML3',
#     u'B07FJQ32BG',
#     u'B00OJOFX2S',
#     u'B01AMJCHB8',
#     u'B07P9TFHB5',
#     u'B00JKK3MAG',
#     u'B07DVRNCYS',
#     u'B07QR1299Y',
#     u'B00CYA4RIK',
#     u'B07GRF5H23',
#     u'B00DS5BG52',
#     u'B079RDR8ZD',
#     u'B07J5Q6XXL',
#     u'B00VX14U6K',
#     u'B01M05I0PJ',
#     u'B07FJQ32BG',
#     u'B07QR1299Y',
#     u'B07J5Q6XXL',
#     u'B07DVRNCYS',
#     u'B010CVCH70',
#     u'B0016QX5RC',
#     u'B07FSMRY3S',
#     u'B07SNFZ9Y1',
#     u'B07RRYLSX9',
#     u'B07PP31LC8',
#     u'B01ATR95E0',
#     u'B07Q5GYQJC',
#     u'B07RX7WYBM',
#     u'B07DM5MLFV',
#     u'B07D7HRVDL',
#     u'B00VKHG5PG',
#     u'B079C73K48',
#     u'B07FWB52YG',
#     u'B07WW5W7L2',
#     u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B0797CG5R8',
#     u'B07SFLZY12',
#     u'B01HN81YL0',
#     u'B00UNT5T04',
#     u'B07RLJ2H1H',
#     u'B01D6AQQQC',
#     u'B07S2C8QKG',
#     u'B00CDKAZY6',
#     u'B008PA091C',
#     u'B000GG6EU8',
#     u'B008FL8KLC',
#     u'B0069SGC72',
#     u'B00U3SMG8S'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 1,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Phoenix',
#      u'customer_zip_code': u'85037',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419176',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 65,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
# ...
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 20, 23, 690821, tzinfo=<UTC>),
#     'total_matches': 1450},
#    'sponsored_asins': [u'B07BHV28DR',
#     u'B07M68BF8R',
#     u'B07JP6HNQC',
#     u'B07RX7WYBM',
#     u'B07VP9LGGQ',
#     u'B07R2MS7ZH',
#     u'B074N2KZXT',
#     u'B074SY4CPN',
#     u'B07MF44P9Z',
#     u'B00T56FQAE',
#     u'B01AMJCHB8',
#     u'B07Y5PCHH7']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'WY'},
#    'max_pages': 3,
#    'page_num': 3,
#    'query': u'biotin',
#    'session_id': u'1eaca5f32bd742539f5fe525ac5db0f9'},
#   'result': {'asins': [u'B07D7WJQQ3',
#     u'B0756TLG77',
#     u'B07Y5PCHH7',
#     u'B003VRBLMA',
#     u'B00Q8MHDCM',
#     u'B07VSSSDR1',
#     u'B001E0T7S6',
#     u'B07FLCLRHS',
#     u'B0788ZN9F6',
#     u'B00KOD1USO',
#     u'B000POUIH6',
#     u'B07VPQ5RJY',
#     u'B007NS7M6M',
#     u'B01CO0CZJW',
#     u'B009SD7OZ4',
#     u'B001RN3ROA',
#     u'B00IBVWXZA',
#     u'B008A5FOXU',
#     u'B074SY4CPN',
#     u'B07S4D8458',
#     u'B001E6O6P4',
#     u'B00QT5R48G',
#     u'B01BOWOR8I',
#     u'B005YVWZVW',
#     u'B07MF44P9Z',
#     u'B000NYG7JG',
#     u'B00YMRO4GI',
#     u'B00OKO1OMK',
#     u'B00KXU5K2U',
#     u'B00DNNZ1DW',
#     u'B000POXU3U',
#     u'B07NVCZ6W4',
#     u'B073H72KYX',
#     u'B07CJXWG8C',
#     u'B008OXWYW2',
#     u'B07J2SP78K',
#     u'B001KYOGMS',
#     u'B074H5784C',
#     u'B01N404FQT',
#     u'B00F0HCXJE',
#     u'B07V2PNPN7',
#     u'B0016K11U6',
#     u'B01M1FZ7ZU',
#     u'B07G1CMLCV',
#     u'B06XW7N4FN',
#     u'B071RSNBBM',
#     u'B00E6K0M8K',
#     u'B001115TLM'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 102,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Cheyenne',
#      u'customer_zip_code': u'82001',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419228',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 60,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 20, 29, 780901, tzinfo=<UTC>),
#     'total_matches': 1450},
#    'sponsored_asins': [u'B07BHV28DR',
#     u'B07M68BF8R',
#     u'B07JP6HNQC',
#     u'B07RX7WYBM',
#     u'B07VP9LGGQ',
#     u'B07Y5PCHH7',
#     u'B07R2MS7ZH',
#     u'B074N2KZXT',
#     u'B019ZZB3O2',
#     u'B07MF44P9Z',
#     u'B00T56FQAE',
#     u'B01AMJCHB8']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'MT'},
#    'max_pages': 3,
#    'page_num': 2,
#    'query': u'biotin',
#    'session_id': u'0abe6348ded949e883a4587d9aa390a8'},
#   'result': {'asins': [u'B000WSS3TA',
#     u'B009P6BI60',
#     u'B00DS5BGAC',
#     u'B008NC7SHU',
#     u'B07Q6BV39V',
#     u'B07VKHZ9MJ',
#     u'B07WFZY7BV',
#     u'B00ZQ0CKJI',
#     u'B074H67KND',
#     u'B072L3KTCH',
#     u'B07CNC9CLD',
#     u'B07B8TFKNK',
#     u'B010CVCH70',
#     u'B07YBN49WL',
#     u'B0084H4XTK',
#     u'B07MK4B3W8',
#     u'B01LDDAI54',
#     u'B000J4FSVS',
#     u'B07HLRW96F',
#     u'B00NV5UTYI',
#     u'B00T5KHWX4',
#     u'B00BPGPX1E',
#     u'B014Q0MWWI',
#     u'B01D6AQR7A',
#     u'B07C5GTS7D',
#     u'B074V7394F',
#     u'B07G9RG2LY',
#     u'B01NCLYPT0',
#     u'B07CW639YG',
#     u'B07R2MS7ZH',
#     u'B008FL8KSA',
#     u'B01G4SQMU8',
#     u'B01C2AI61K',
#     u'B01M216P3O',
#     u'B075DJ52VS',
#     u'B00NIXBUMS',
#     u'B01FRG6EQ0',
#     u'B074N2KZXT',
#     u'B07KKN1N2Y',
#     u'B07L9Q9L3N',
#     u'B019TP6S6G',
#     u'B071WT2VZN',
#     u'B00H540TA0',
#     u'B0012DZIII',
#     u'B01FV7PSAI',
#     u'B01GNBMAMU',
#     u'B00UW3LFTA',
#     u'B00Q5RPIE0'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 49,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Billings',
#      u'customer_zip_code': u'59102',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419229',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 60,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 20, 31, 557340, tzinfo=<UTC>),
#     'total_matches': 712},
#    'sponsored_asins': [u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B00T56FQAE',
#     u'B07VP9LGGQ',
#     u'B07R2MS7ZH',
#     u'B07MXR3WJL',
#     u'B07QR1299Y',
#     u'B07Y5PCHH7',
#     u'B01AMJCHB8',
#     u'B07MF44P9Z',
#     u'B019ZZB3O2',
#     u'B00IOZWC2M']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'AK'},
#    'max_pages': 3,
#    'page_num': 2,
#    'query': u'biotin',
#    'session_id': u'5a53ccd8edbe43cfba0c83bfc23245b0'},
#   'result': {'asins': [u'B000WSS3TA',
#     u'B009P6BI60',
#     u'B07MK4B3W8',
#     u'B00DS5BGAC',
#     u'B07WFZY7BV',
#     u'B008NC7SHU',
#     u'B07VKHZ9MJ',
#     u'B07Q6BV39V',
#     u'B00ZQ0CKJI',
#     u'B074H67KND',
#     u'B072L3KTCH',
#     u'B07B8TFKNK',
#     u'B07CNC9CLD',
#     u'B07PG1XK8P',
#     u'B010CVCH70',
#     u'B07YBN49WL',
#     u'B0084H4XTK',
#     u'B01LDDAI54',
#     u'B000J4FSVS',
#     u'B07HLRW96F',
#     u'B00NV5UTYI',
#     u'B00T5KHWX4',
#     u'B07C5GTS7D',
#     u'B00BPGPX1E',
#     u'B014Q0MWWI',
#     u'B01C2AI61K',
#     u'B01D6AQR7A',
#     u'B074V7394F',
#     u'B07G9RG2LY',
#     u'B01NCLYPT0',
#     u'B07CW639YG',
#     u'B07R2MS7ZH',
#     u'B008FL8KSA',
#     u'B01G4SQMU8',
#     u'B00NIXBUMS',
#     u'B00H540TA0',
#     u'B07KKN1N2Y',
#     u'B01M216P3O',
#     u'B075DJ52VS',
#     u'B01FRG6EQ0',
#     u'B074N2KZXT',
#     u'B07L9Q9L3N',
#     u'B019TP6S6G',
#     u'B071WT2VZN',
#     u'B0012DZIII',
#     u'B00Q5RPIE0',
#     u'B01FV7PSAI',
#     u'B00RLV358A'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 54,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Anchorage',
#      u'customer_zip_code': u'99508',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419228',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 60,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 20, 31, 913360, tzinfo=<UTC>),
#     'total_matches': 712},
#    'sponsored_asins': [u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B00T56FQAE',
#     u'B07VP9LGGQ',
#     u'B00IOZWC2M',
#     u'B07QR1299Y',
#     u'B07Y5PCHH7',
#     u'B07MXR3WJL',
#     u'B01AMJCHB8',
#     u'B07MF44P9Z',
#     u'B019ZZB3O2',
#     u'B07R2MS7ZH']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'MT'},
#    'max_pages': 3,
#    'page_num': 3,
#    'query': u'biotin',
#    'session_id': u'0abe6348ded949e883a4587d9aa390a8'},
#   'result': {'asins': [u'B01GNBMAMU',
#     u'B07GZCN4FH',
#     u'B07816TG17',
#     u'B000HHQJW4',
#     u'B071FF5JW2',
#     u'B012EU6GVA',
#     u'B016IRQTSU',
#     u'B07GRC5KFK',
#     u'B005C80W7Q',
#     u'B00U52PASK',
#     u'B00028OF06',
#     u'B0752XHNBH',
#     u'B07XV7FVW3',
#     u'B00GK7A3MM',
#     u'B012FTTF5O',
#     u'B07D7WJQQ3',
#     u'B0756TLG77',
#     u'B07Y5PCHH7',
#     u'B003VRBLMA',
#     u'B00Q8MHDCM',
#     u'B07VSSSDR1',
#     u'B001E0T7S6',
#     u'B07FLCLRHS',
#     u'B0788ZN9F6',
#     u'B00KOD1USO',
#     u'B000POUIH6',
#     u'B07VPQ5RJY',
#     u'B007NS7M6M',
#     u'B01CO0CZJW',
#     u'B009SD7OZ4',
#     u'B001RN3ROA',
#     u'B00IBVWXZA',
#     u'B008A5FOXU',
#     u'B074SY4CPN',
#     u'B07S4D8458',
#     u'B001E6O6P4',
#     u'B00QT5R48G',
#     u'B01BOWOR8I',
#     u'B005YVWZVW',
#     u'B07MF44P9Z',
#     u'B000NYG7JG',
#     u'B00YMRO4GI',
#     u'B00OKO1OMK',
#     u'B00KXU5K2U',
#     u'B00DNNZ1DW',
#     u'B000POXU3U',
#     u'B07NVCZ6W4',
#     u'B073H72KYX'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 97,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Billings',
#      u'customer_zip_code': u'59102',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419232',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 60,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 20, 34, 426335, tzinfo=<UTC>),
#     'total_matches': 1450},
#    'sponsored_asins': [u'B07BHV28DR',
#     u'B07M68BF8R',
#     u'B07JP6HNQC',
#     u'B07RX7WYBM',
#     u'B07VP9LGGQ',
#     u'B07Y5PCHH7',
#     u'B07R2MS7ZH',
#     u'B074N2KZXT',
#     u'B019ZZB3O2',
#     u'B07MF44P9Z',
#     u'B00T56FQAE',
#     u'B01AMJCHB8']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'TX'},
#    'max_pages': 3,
#    'page_num': 3,
#    'query': u'biotin',
#    'session_id': u'03b7720b5308418f9e86e69eee22870d'},
#   'result': {'asins': [u'B01GNBMAMU',
#     u'B07GZCN4FH',
#     u'B07816TG17',
#     u'B000HHQJW4',
#     u'B071FF5JW2',
#     u'B012EU6GVA',
#     u'B016IRQTSU',
#     u'B07GRC5KFK',
#     u'B005C80W7Q',
#     u'B00U52PASK',
#     u'B00028OF06',
#     u'B0752XHNBH',
#     u'B07XV7FVW3',
#     u'B00GK7A3MM',
#     u'B012FTTF5O',
#     u'B07D7WJQQ3',
#     u'B0756TLG77',
#     u'B07Y5PCHH7',
#     u'B003VRBLMA',
#     u'B00Q8MHDCM',
#     u'B07VSSSDR1',
#     u'B001E0T7S6',
#     u'B07FLCLRHS',
#     u'B0788ZN9F6',
#     u'B00KOD1USO',
#     u'B000POUIH6',
#     u'B07VPQ5RJY',
#     u'B007NS7M6M',
#     u'B01CO0CZJW',
#     u'B009SD7OZ4',
#     u'B001RN3ROA',
#     u'B00IBVWXZA',
#     u'B008A5FOXU',
#     u'B074SY4CPN',
#     u'B07S4D8458',
#     u'B001E6O6P4',
#     u'B00QT5R48G',
#     u'B01BOWOR8I',
#     u'B005YVWZVW',
#     u'B07MF44P9Z',
#     u'B000NYG7JG',
#     u'B00YMRO4GI',
#     u'B00OKO1OMK',
#     u'B00KXU5K2U',
#     u'B00DNNZ1DW',
#     u'B000POXU3U',
#     u'B07NVCZ6W4',
#     u'B073H72KYX'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 102,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'El Paso',
#      u'customer_zip_code': u'79902',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419225',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 60,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 20, 35, 64939, tzinfo=<UTC>),
#     'total_matches': 1425},
#    'sponsored_asins': [u'B07BHV28DR',
#     u'B07M68BF8R',
#     u'B07JP6HNQC',
#     u'B07RX7WYBM',
#     u'B07Y5PCHH7',
#     u'B07VP9LGGQ',
#     u'B074N2KZXT',
#     u'B074SY4CPN',
#     u'B019ZZB3O2',
#     u'B07JM48VY7',
#     u'B00T56FQAE',
#     u'B01AMJCHB8']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'WV'},
#    'max_pages': 3,
#    'page_num': 3,
#    'query': u'biotin',
#    'session_id': u'6ab7fd6683e14d2e9027432c29cb16b4'},
#   'result': {'asins': [u'B071WT2VZN',
#     u'B0012DZIII',
#     u'B00Q5RPIE0',
#     u'B01FV7PSAI',
#     u'B00RLV358A',
#     u'B01GNBMAMU',
#     u'B015QFMNZI',
#     u'B07GZCN4FH',
#     u'B00EODALHQ',
#     u'B000HHQJW4',
#     u'B071FF5JW2',
#     u'B012EU6GVA',
#     u'B016IRQTSU',
#     u'B07GRC5KFK',
#     u'B005C80W7Q',
#     u'B00U52PASK',
#     u'B07SCXCP4S',
#     u'B00028OF06',
#     u'B0752XHNBH',
#     u'B01LQEMAJM',
#     u'B07XV7FVW3',
#     u'B00GK7A3MM',
#     u'B012FTTF5O',
#     u'B07D7WJQQ3',
#     u'B0756TLG77',
#     u'B07Y5PCHH7',
#     u'B003VRBLMA',
#     u'B00Q8MHDCM',
#     u'B07VSSSDR1',
#     u'B001E0T7S6',
#     u'B07FLCLRHS',
#     u'B0788ZN9F6',
#     u'B00KOD1USO',
#     u'B000POUIH6',
#     u'B07VPQ5RJY',
#     u'B007NS7M6M',
#     u'B00DNNZ1DW',
#     u'B01CO0CZJW',
#     u'B009SD7OZ4',
#     u'B001RN3ROA',
#     u'B00IBVWXZA',
#     u'B008A5FOXU',
#     u'B074SY4CPN',
#     u'B07S4D8458',
#     u'B001E6O6P4',
#     u'B00QT5R48G',
#     u'B01BOWOR8I',
#     u'B005YVWZVW'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 102,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Martinsburg',
#      u'customer_zip_code': u'25403',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419241',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 60,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 20, 43, 841353, tzinfo=<UTC>),
#     'total_matches': 22834},
#    'sponsored_asins': [u'B07BHV28DR',
#     u'B07M68BF8R',
#     u'B07JP6HNQC',
#     u'B07RX7WYBM',
#     u'B07Y5PCHH7',
#     u'B07VP9LGGQ',
#     u'B07R2MS7ZH',
#     u'B074N2KZXT',
#     u'B019ZZB3O2',
#     u'B07MF44P9Z',
#     u'B00T56FQAE',
#     u'B01AMJCHB8']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'NH'},
#    'max_pages': 3,
#    'page_num': 2,
#    'query': u'biotin',
#    'session_id': u'5dcfb944de8e437f8bfedd4bc4ea5632'},
#   'result': {'asins': [u'B000WSS3TA',
#     u'B009P6BI60',
#     u'B07MK4B3W8',
#     u'B00DS5BGAC',
#     u'B008NC7SHU',
#     u'B07Q6BV39V',
#     u'B07VKHZ9MJ',
#     u'B07WFZY7BV',
#     u'B00ZQ0CKJI',
#     u'B074H67KND',
#     u'B072L3KTCH',
#     u'B07CNC9CLD',
#     u'B07B8TFKNK',
#     u'B010CVCH70',
#     u'B07MXR3WJL',
#     u'B07YBN49WL',
#     u'B0084H4XTK',
#     u'B00YR8M5JA',
#     u'B01LDDAI54',
#     u'B000J4FSVS',
#     u'B07HLRW96F',
#     u'B00NV5UTYI',
#     u'B00T5KHWX4',
#     u'B07NDNQLKS',
#     u'B00BPGPX1E',
#     u'B01C2AI61K',
#     u'B014Q0MWWI',
#     u'B01D6AQR7A',
#     u'B07C5GTS7D',
#     u'B074V7394F',
#     u'B07G9RG2LY',
#     u'B01ENCBOA0',
#     u'B01NCLYPT0',
#     u'B07CW639YG',
#     u'B07R2MS7ZH',
#     u'B008FL8KSA',
#     u'B01G4SQMU8',
#     u'B07S8Y49N1',
#     u'B01M216P3O',
#     u'B075DJ52VS',
#     u'B00NIXBUMS',
#     u'B07816TG17',
#     u'B01FRG6EQ0',
#     u'B074N2KZXT',
#     u'B07KKN1N2Y',
#     u'B07L9Q9L3N',
#     u'B019TP6S6G',
#     u'B071WT2VZN'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 49,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Dover',
#      u'customer_zip_code': u'03820',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419242',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 60,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 20, 44, 248664, tzinfo=<UTC>),
#     'total_matches': 8128},
#    'sponsored_asins': [u'B07M68BF8R',
#     u'B07BHV28DR',
#     u'B00T56FQAE',
#     u'B07VP9LGGQ',
#     u'B07R2MS7ZH',
#     u'B07MXR3WJL',
#     u'B07QR1299Y',
#     u'B07Y5PCHH7',
#     u'B01AMJCHB8',
#     u'B07MF44P9Z',
#     u'B019ZZB3O2',
#     u'B00IOZWC2M']}},
#  {'args': {'ip_loc': {'country': u'US', 'state': u'AK'},
#    'max_pages': 3,
#    'page_num': 3,
#    'query': u'biotin',
#    'session_id': u'5a53ccd8edbe43cfba0c83bfc23245b0'},
#   'result': {'asins': [u'B07SFLZY12',
#     u'B00Q5RPIE0',
#     u'B00RLV358A',
#     u'B07GZCN4FH',
#     u'B000HHQJW4',
#     u'B07S2C8QKG',
#     u'B01ATR95E0',
#     u'B012EU6GVA',
#     u'B071FF5JW2',
#     u'B00U52PASK',
#     u'B00028OF06',
#     u'B016IRQTSU',
#     u'B07XV7FVW3',
#     u'B07GRC5KFK',
#     u'B005C80W7Q',
#     u'B00GK7A3MM',
#     u'B012FTTF5O',
#     u'B07D7WJQQ3',
#     u'B07Y5PCHH7',
#     u'B003VRBLMA',
#     u'B07VSSSDR1',
#     u'B001E0T7S6',
#     u'B009P6BI60',
#     u'B07FLCLRHS',
#     u'B0756TLG77',
#     u'B0788ZN9F6',
#     u'B01LQEMAJM',
#     u'B00Q8MHDCM',
#     u'B000POUIH6',
#     u'B07VPQ5RJY',
#     u'B007NS7M6M',
#     u'B01CO0CZJW',
#     u'B009SD7OZ4',
#     u'B001RN3ROA',
#     u'B00DNNZ1DW',
#     u'B00IBVWXZA',
#     u'B008A5FOXU',
#     u'B00KOD1USO',
#     u'B074SY4CPN',
#     u'B07S4D8458',
#     u'B07RLJ2H1H',
#     u'B010DZPGUU',
#     u'B00QT5R48G',
#     u'B005YVWZVW',
#     u'B07MF44P9Z',
#     u'B000NYG7JG',
#     u'B00OKO1OMK',
#     u'B000POXU3U'],
#    'details': [],
#    'meta': {'date': datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<UTC>),
#     'first_rank': 102,
#     'internal': {u'country_code': u'US',
#      u'customer_city': u'Anchorage',
#      u'customer_zip_code': u'99508',
#      u'device': u'DESKTOP',
#      u'marketplace_id': u'1',
#      u'query_id': u'1571419254',
#      u'store': u'gateway',
#      u'triggered_weblabs': u'SEARCH_133418:T1'},
#     'parser': {u'num_products': 60,
#      u'num_sponsored': 12,
#      u'version': u'20191017'},
#     'time': datetime.datetime(2019, 10, 18, 17, 20, 58, 937331, tzinfo=<UTC>),
#     'total_matches': 26664},
#    'sponsored_asins': [u'B07BHV28DR',
#     u'B07M68BF8R',
#     u'B07JP6HNQC',
#     u'B07RX7WYBM',
#     u'B07VP9LGGQ',
#     u'B07R2MS7ZH',
#     u'B074N2KZXT',
#     u'B074SY4CPN',
#     u'B07MF44P9Z',
#     u'B00T56FQAE',
#     u'B01AMJCHB8',
#     u'B07Y5PCHH7']}}]
