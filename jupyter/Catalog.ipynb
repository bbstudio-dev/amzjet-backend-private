# %%
import os
import pandas as pd
import flask
import jmespath
import pymongo
from flask_classful import FlaskView, route
from flask_jwt_extended import current_user, jwt_required

import amz_local_search.analysis as sd
import amz_local_search.artifacts.asin_report as asin_report_artifact
import amz_local_search.artifacts.search as search_artifact
import bb_utils.time.utils as tu
from amz_local_search.base.action_logger import (ActionContext, ActionError,
                                                 ActionState)
from amz_local_search.base.celery_job import celery_client
from amz_local_search.base.errors import (UserResourceNotFound,
                                          UserUsageLimitExceeded)
from amz_local_search.base.instances import action_logger, artifact_updater
from amz_local_search.config import get_config
from bb_utils.time.utils import utc_time
from web_app_api.extensions import get_user_id_from_jwt
from web_app_api.utils import proxy_to_obj
from bb_utils.utils.mmh3_hash import json_to_hash128_s

# %%
def connect_to_mongo_db():
    mongo_uri = get_config().mongo_local_search_db_uri()
    client = pymongo.MongoClient(mongo_uri)
    return client.get_database()


def merge_two_dicts(x, y):
    z = x.copy()
    z.update(y)
    return z


class Catalog(FlaskView):
    route_prefix = 'api/local-search/query'

    def get_asins_meta(self, mongo_db, asins):
        product_details = dict(
            (p['asin'], p)
            for p in mongo_db.products.find({'_id': {
                '$in': asins
            }}))
        return product_details

    def asin_report_key(self, query, asin):
        return json_to_hash128_s([query, asin])

    def get_asin_reports_from_actions(self, mongo_db, user_id,
                                      scan_depth=10000):
        matches = mongo_db.actions.find(
            {
                'user.id': user_id,
                'action_sig': 'amz_local_search.report(query, asin)',
                'state.success': True,
                'args.asin': {
                    '$nin': ['@latest', '@LATEST']
                }
            }, {
                'args.asin': 1,
                'args.query': 1,
                'occurred_at': 1
            }).sort([('occurred_at', -1)]).limit(scan_depth)

        reports = {}
        for match in matches:
            asin = match['args'].get('asin', '').strip()
            query = match['args'].get('query', '').strip()

            if not asin or asin.startswith('@'):
                continue

            key = self.asin_report_key(query, asin)

            report = reports.get(key)
            if report:
                report['frequency'] = report['frequency'] + 1
            else:
                reports[key] = {
                    'key': key,
                    'query': query,
                    'asin': asin,
                    'timestamp': match['occurred_at'],
                    'frequency': 1
                }
        return reports

# %%
mongo_db = connect_to_mongo_db()
user_id = 1

catalog = Catalog()
reports = catalog.get_asin_reports_from_actions(mongo_db, user_id)
reports
# Out:
# {'2KiodrgdzGqYjWRMFJL6Vj': {'asin': u'B07RFL8J76',
#   'frequency': 2,
#   'key': '2KiodrgdzGqYjWRMFJL6Vj',
#   'query': u'carabiner clip',
#   'timestamp': datetime.datetime(2019, 11, 1, 18, 59, 15, 915000)},
#  '4Krb38NF5JXtqPvV2NDkUC': {'asin': u'B07DD9RQFF',
#   'frequency': 1,
#   'key': '4Krb38NF5JXtqPvV2NDkUC',
#   'query': u'b07dd9rqff',
#   'timestamp': datetime.datetime(2019, 10, 17, 5, 24, 28, 518000)},
#  '4Y77FXZPmTpnxmHGj3FJjj': {'asin': u'B00T56FQAE',
#   'frequency': 1,
#   'key': '4Y77FXZPmTpnxmHGj3FJjj',
#   'query': u'biotin',
#   'timestamp': datetime.datetime(2019, 10, 18, 7, 10, 15, 39000)},
#  '55WckJx2QMN3amjM63iwye': {'asin': u'B006SFUDT4',
#   'frequency': 2,
#   'key': '55WckJx2QMN3amjM63iwye',
#   'query': u'bath toy organizer',
#   'timestamp': datetime.datetime(2019, 11, 1, 19, 2, 1, 551000)},
#  '5GXurd6zjKy3FNCoviXHoj': {'asin': u'B013NNG18U',
#   'frequency': 57,
#   'key': '5GXurd6zjKy3FNCoviXHoj',
#   'query': u'carabiner clip',
#   'timestamp': datetime.datetime(2019, 12, 13, 21, 11, 32, 807000)},
#  '6ab8B8y7BTjEdrhRwN33EU': {'asin': u'B07VC529JB',
#   'frequency': 3,
#   'key': '6ab8B8y7BTjEdrhRwN33EU',
#   'query': u'weather proof furniture',
#   'timestamp': datetime.datetime(2019, 10, 18, 19, 50, 44, 161000)},
#  '6rZSvjJuQ6VArhW3B5gpvW': {'asin': u'B072NCYVQK',
#   'frequency': 25,
#   'key': '6rZSvjJuQ6VArhW3B5gpvW',
#   'query': u'carabiner clip',
#   'timestamp': datetime.datetime(2019, 11, 29, 20, 18, 56, 897000)},
#  'B7Cx9HT4aKR7HzMkUDM9yC': {'asin': u'B07SZ4VP91',
#   'frequency': 2,
#   'key': 'B7Cx9HT4aKR7HzMkUDM9yC',
#   'query': u'carabiner clip',
#   'timestamp': datetime.datetime(2019, 11, 2, 6, 30, 33, 385000)},
#  'B8LnPiTUYEaLsYxLYHrQxL': {'asin': u'B01M6ZFU02',
#   'frequency': 9,
#   'key': 'B8LnPiTUYEaLsYxLYHrQxL',
#   'query': u'bath toy organizer',
#   'timestamp': datetime.datetime(2019, 10, 16, 3, 0, 49, 222000)},
#  'B9j9SSSg4nDswY9w74GN5e': {'asin': u'B000MVQBG4',
#   'frequency': 3,
#   'key': 'B9j9SSSg4nDswY9w74GN5e',
#   'query': u'bath toy organizer',
#   'timestamp': datetime.datetime(2019, 11, 1, 19, 2, 18, 533000)},
#  'CyX8GKNU6Y2kNh4wJvtkAf': {'asin': u'1999896963',
#   'frequency': 2,
#   'key': 'CyX8GKNU6Y2kNh4wJvtkAf',
#   'query': u'coloring book',
#   'timestamp': datetime.datetime(2019, 10, 11, 4, 23, 16, 319000)},
#  'DkTKSeoAviKwHftPhkYngJ': {'asin': u'UNDEFINED',
#   'frequency': 47,
#   'key': 'DkTKSeoAviKwHftPhkYngJ',
#   'query': u'carabiner clip',
#   'timestamp': datetime.datetime(2019, 12, 3, 19, 23, 52, 759000)},
#  'FD8WbYNHt6cVUXs3Q8xQbQ': {'asin': u'XYZ',
#   'frequency': 3,
#   'key': 'FD8WbYNHt6cVUXs3Q8xQbQ',
#   'query': u'carabiner clip',
#   'timestamp': datetime.datetime(2019, 11, 30, 7, 3, 48, 934000)},
#  'FKZJFxAmvvfWNa4E7aFzoh': {'asin': u'B009SZXM4E',
#   'frequency': 1,
#   'key': 'FKZJFxAmvvfWNa4E7aFzoh',
#   'query': u'biotin',
#   'timestamp': datetime.datetime(2019, 10, 18, 7, 9, 56, 915000)},
#  'G8VFU9QePM98hf7ijhFeCn': {'asin': u'0525568077',
#   'frequency': 1,
#   'key': 'G8VFU9QePM98hf7ijhFeCn',
#   'query': u'carabiner clip',
#   'timestamp': datetime.datetime(2019, 10, 16, 3, 5, 27, 938000)},
#  'JKWywnNPFsSdfq83XtMaHb': {'asin': u'B07W1KDNRV',
#   'frequency': 1,
#   'key': 'JKWywnNPFsSdfq83XtMaHb',
#   'query': u'outdoor dog fence system',
#   'timestamp': datetime.datetime(2019, 10, 16, 1, 3, 21, 38000)},
#  'L4grc8oZwu2AhJy2o3gHWa': {'asin': u'0692927999',
#   'frequency': 1,
#   'key': 'L4grc8oZwu2AhJy2o3gHWa',
#   'query': u'coloring book',
#   'timestamp': datetime.datetime(2019, 10, 11, 4, 22, 45, 452000)},
#  'Ld24AaWev3qwyFN3eSUyZ2': {'asin': u'B07RMKR1GB',
#   'frequency': 1,
#   'key': 'Ld24AaWev3qwyFN3eSUyZ2',
#   'query': u'emergency lantern',
#   'timestamp': datetime.datetime(2019, 10, 15, 2, 9, 52, 408000)},
#  'RnRuCtyHqJwGY7LZCHJh7T': {'asin': u'B00ZTNK8FA',
#   'frequency': 1,
#   'key': 'RnRuCtyHqJwGY7LZCHJh7T',
#   'query': u'weather proof furniture',
#   'timestamp': datetime.datetime(2019, 10, 16, 3, 55, 16, 847000)},
#  'TaZXYtggcD5dJMkekoc263': {'asin': u'B07KT6BM9Y',
#   'frequency': 1,
#   'key': 'TaZXYtggcD5dJMkekoc263',
#   'query': u'bath toy organizer',
#   'timestamp': datetime.datetime(2019, 10, 16, 3, 1, 39, 111000)},
#  'UEX5crJ5HYhfFytQ8DkjnT': {'asin': u'B06W9NCZYX',
#   'frequency': 1,
#   'key': 'UEX5crJ5HYhfFytQ8DkjnT',
#   'query': u'toys for little brothers',
#   'timestamp': datetime.datetime(2019, 10, 16, 3, 52, 11, 769000)},
#  'WEepzdhygS395iLP5vsgXN': {'asin': u'B07TV1TRDR',
#   'frequency': 6,
#   'key': 'WEepzdhygS395iLP5vsgXN',
#   'query': u'carabiner clip',
#   'timestamp': datetime.datetime(2019, 11, 27, 19, 24, 36, 278000)},
#  'WLS8tkSFofWx7Tdmtoc4kH': {'asin': u'B076ZVX8TM',
#   'frequency': 1,
#   'key': 'WLS8tkSFofWx7Tdmtoc4kH',
#   'query': u'toys for little brothers',
#   'timestamp': datetime.datetime(2019, 10, 16, 3, 52, 28, 495000)},
#  'WsGWVYiGDa9Wf3Vn3R5ESH': {'asin': u'B07TT353XQ',
#   'frequency': 29,
#   'key': 'WsGWVYiGDa9Wf3Vn3R5ESH',
#   'query': u'carabiner clip',
#   'timestamp': datetime.datetime(2019, 12, 1, 6, 27, 25, 154000)},
#  'XGfvbMB75ZtCA5aYq8gQT2': {'asin': u'B07RFD9P55',
#   'frequency': 2,
#   'key': 'XGfvbMB75ZtCA5aYq8gQT2',
#   'query': u'outdoor dog fence system',
#   'timestamp': datetime.datetime(2019, 10, 19, 8, 19, 48, 839000)},
#  'Z7aNboQ8DL9V43FyoxnaLo': {'asin': u'B0001ZWZ8O',
#   'frequency': 1,
#   'key': 'Z7aNboQ8DL9V43FyoxnaLo',
#   'query': u'outdoor dog fence system',
#   'timestamp': datetime.datetime(2019, 10, 19, 8, 19, 42, 704000)},
#  'ZWqCPVYdij5U6PqQiBcy82': {'asin': u'0071774351',
#   'frequency': 1,
#   'key': 'ZWqCPVYdij5U6PqQiBcy82',
#   'query': u'outdoor dog fence system',
#   'timestamp': datetime.datetime(2019, 12, 3, 6, 52, 51, 296000)},
#  'ZwZpGWsQH2SeZyHSvs4HrV': {'asin': u'B018L2WM86',
#   'frequency': 1,
#   'key': 'ZwZpGWsQH2SeZyHSvs4HrV',
#   'query': u'emergency lantern',
#   'timestamp': datetime.datetime(2019, 10, 16, 3, 4, 29, 880000)},
#  'a2ao6MJQBRH5ZetSkmKMEB': {'asin': u'B00NPLSZF8',
#   'frequency': 1,
#   'key': 'a2ao6MJQBRH5ZetSkmKMEB',
#   'query': u'emergency lantern',
#   'timestamp': datetime.datetime(2019, 10, 16, 3, 15, 46, 62000)},
#  'aexwk7RJckGVFXFgjCwq4c': {'asin': u'B073GJ59QM',
#   'frequency': 16,
#   'key': 'aexwk7RJckGVFXFgjCwq4c',
#   'query': u'carabiner clip',
#   'timestamp': datetime.datetime(2019, 12, 3, 19, 55, 40, 611000)},
#  'b8rUFpe3RLPadSLvd5fNvW': {'asin': u'B0719B4LNH',
#   'frequency': 37,
#   'key': 'b8rUFpe3RLPadSLvd5fNvW',
#   'query': u'carabiner clip',
#   'timestamp': datetime.datetime(2019, 12, 3, 19, 55, 28, 948000)},
#  'brSeE5xBXw8gEV2PQfAUnX': {'asin': u'B01DAPMQO4',
#   'frequency': 3,
#   'key': 'brSeE5xBXw8gEV2PQfAUnX',
#   'query': u'bath toy organizer',
#   'timestamp': datetime.datetime(2019, 11, 1, 19, 2, 11, 320000)},
#  'dDMmBHZmupmy6VrunGiBJ6': {'asin': u'UNDEFINED',
#   'frequency': 2,
#   'key': 'dDMmBHZmupmy6VrunGiBJ6',
#   'query': u'outdoor dog fence system',
#   'timestamp': datetime.datetime(2019, 12, 3, 9, 28, 29, 691000)},
#  'fpjXARyNhnEiQCdi5SZCQo': {'asin': u'B07GQV8H5V',
#   'frequency': 5,
#   'key': 'fpjXARyNhnEiQCdi5SZCQo',
#   'query': u'carabiner clip',
#   'timestamp': datetime.datetime(2019, 11, 29, 21, 48, 5, 981000)},
#  'g8awJjkeHrakJCBzXPAsRX': {'asin': u'B016MAVG86',
#   'frequency': 1,
#   'key': 'g8awJjkeHrakJCBzXPAsRX',
#   'query': u'weather proof furniture',
#   'timestamp': datetime.datetime(2019, 10, 16, 3, 55, 48, 929000)},
#  'gk32QoaEwZeumGPUr2CGYD': {'asin': u'B07DNHV7X9',
#   'frequency': 1,
#   'key': 'gk32QoaEwZeumGPUr2CGYD',
#   'query': u'outdoor dog fence system',
#   'timestamp': datetime.datetime(2019, 10, 19, 8, 19, 8, 376000)},
#  'gyRw8czMh4LLzBxdPJd2Si': {'asin': u'B00IOZWC2M',
#   'frequency': 1,
#   'key': 'gyRw8czMh4LLzBxdPJd2Si',
#   'query': u'biotin',
#   'timestamp': datetime.datetime(2019, 10, 18, 7, 10, 9, 525000)},
#  'gzjLwawo8EKUTBBqpnQ9DW': {'asin': u'B07VH4GK85',
#   'frequency': 1,
#   'key': 'gzjLwawo8EKUTBBqpnQ9DW',
#   'query': u'weather proof furniture',
#   'timestamp': datetime.datetime(2019, 10, 16, 4, 4, 1, 100000)},
#  'hBkD5W7xYgNVgKH3dDmgiF': {'asin': u'B01C5QSENQ',
#   'frequency': 5,
#   'key': 'hBkD5W7xYgNVgKH3dDmgiF',
#   'query': u'emergency lantern',
#   'timestamp': datetime.datetime(2019, 10, 16, 3, 15, 39, 947000)},
#  'kLwPPSW6K2HQqhHhyxyEeU': {'asin': u'B07CWKGZYL',
#   'frequency': 19,
#   'key': 'kLwPPSW6K2HQqhHhyxyEeU',
#   'query': u'carabiner clip',
#   'timestamp': datetime.datetime(2019, 10, 16, 3, 4, 58, 480000)},
#  'mmVYacPfTQ5BaK8km72fXL': {'asin': u'B073DXLPZ9',
#   'frequency': 10,
#   'key': 'mmVYacPfTQ5BaK8km72fXL',
#   'query': u'carabiner clip',
#   'timestamp': datetime.datetime(2019, 10, 21, 6, 19, 36, 465000)},
#  'nHtmgZqYqE5JEjy3UraHPD': {'asin': u'B07JK9DYNR',
#   'frequency': 5,
#   'key': 'nHtmgZqYqE5JEjy3UraHPD',
#   'query': u'carabiner clip',
#   'timestamp': datetime.datetime(2019, 10, 21, 6, 19, 24, 165000)},
#  'nu6XhYPZYAcvQehPP5ubtY': {'asin': u'B07X9962NK',
#   'frequency': 2,
#   'key': 'nu6XhYPZYAcvQehPP5ubtY',
#   'query': u'outdoor dog fence system',
#   'timestamp': datetime.datetime(2019, 10, 14, 19, 5, 31, 398000)},
#  'pbVDgQKZixxPKi9DQUZVcj': {'asin': u'0071357807',
#   'frequency': 2,
#   'key': 'pbVDgQKZixxPKi9DQUZVcj',
#   'query': u'outdoor dog fence system',
#   'timestamp': datetime.datetime(2019, 12, 3, 7, 8, 28, 939000)},
#  'rZ2yaN3rhtMTUXFs5mnTED': {'asin': u'B07MJ7N6VW',
#   'frequency': 3,
#   'key': 'rZ2yaN3rhtMTUXFs5mnTED',
#   'query': u'coloring book',
#   'timestamp': datetime.datetime(2019, 12, 4, 7, 12, 21, 880000)},
#  'tWT2D2wnPbDr6g2Frwo2LB': {'asin': u'B077YNNT54',
#   'frequency': 3,
#   'key': 'tWT2D2wnPbDr6g2Frwo2LB',
#   'query': u'bath toy organizer',
#   'timestamp': datetime.datetime(2019, 10, 16, 2, 57, 31, 588000)},
#  'uGrWdiQrBiT5HWkYXm7jq7': {'asin': u'B07DD9RQFF',
#   'frequency': 2,
#   'key': 'uGrWdiQrBiT5HWkYXm7jq7',
#   'query': u'carabiner clip',
#   'timestamp': datetime.datetime(2019, 11, 2, 6, 30, 48, 428000)},
#  'uVQ2Tj2m7ZhZcQcJ5PokVC': {'asin': u'B07QH1YW88',
#   'frequency': 29,
#   'key': 'uVQ2Tj2m7ZhZcQcJ5PokVC',
#   'query': u'carabiner clip',
#   'timestamp': datetime.datetime(2019, 12, 4, 1, 33, 24, 729000)},
#  'vZnSTJ9X3qHWEM8dXJoCWL': {'asin': u'B07JJZTYSV',
#   'frequency': 2,
#   'key': 'vZnSTJ9X3qHWEM8dXJoCWL',
#   'query': u'carabiner clip',
#   'timestamp': datetime.datetime(2019, 10, 17, 6, 32, 3, 857000)},
#  'zdi93LeGfPKAaQSoYs8PkV': {'asin': u'1945710799',
#   'frequency': 5,
#   'key': 'zdi93LeGfPKAaQSoYs8PkV',
#   'query': u'coloring book',
#   'timestamp': datetime.datetime(2019, 10, 16, 1, 3, 25, 422000)}}

# %%
reports_df = pd.DataFrame(reports.values())
reports_df.head(3)
# Out:
#          asin  frequency                     key                     query  \
# 0  B07W1KDNRV          1  JKWywnNPFsSdfq83XtMaHb  outdoor dog fence system
# 1  B07TV1TRDR          6  WEepzdhygS395iLP5vsgXN            carabiner clip
# 2  B0001ZWZ8O          1  Z7aNboQ8DL9V43FyoxnaLo  outdoor dog fence system
#
#                 timestamp
# 0 2019-10-16 01:03:21.038
# 1 2019-11-27 19:24:36.278
# 2 2019-10-19 08:19:42.704

# %%
reports_df.groupby(['query']).apply(lambda g: g.sort_values(by=['frequency', 'timestamp'], ascending=[False, True]).to_dict(orient='records')).to_dict()
# Out:
# {u'b07dd9rqff': [{'asin': u'B07DD9RQFF',
#    'frequency': 1,
#    'key': '4Krb38NF5JXtqPvV2NDkUC',
#    'query': u'b07dd9rqff',
#    'timestamp': Timestamp('2019-10-17 05:24:28.518000')}],
#  u'bath toy organizer': [{'asin': u'B01M6ZFU02',
#    'frequency': 9,
#    'key': 'B8LnPiTUYEaLsYxLYHrQxL',
#    'query': u'bath toy organizer',
#    'timestamp': Timestamp('2019-10-16 03:00:49.222000')},
#   {'asin': u'B077YNNT54',
#    'frequency': 3,
#    'key': 'tWT2D2wnPbDr6g2Frwo2LB',
#    'query': u'bath toy organizer',
#    'timestamp': Timestamp('2019-10-16 02:57:31.588000')},
#   {'asin': u'B01DAPMQO4',
#    'frequency': 3,
#    'key': 'brSeE5xBXw8gEV2PQfAUnX',
#    'query': u'bath toy organizer',
#    'timestamp': Timestamp('2019-11-01 19:02:11.320000')},
#   {'asin': u'B000MVQBG4',
#    'frequency': 3,
#    'key': 'B9j9SSSg4nDswY9w74GN5e',
#    'query': u'bath toy organizer',
#    'timestamp': Timestamp('2019-11-01 19:02:18.533000')},
#   {'asin': u'B006SFUDT4',
#    'frequency': 2,
#    'key': '55WckJx2QMN3amjM63iwye',
#    'query': u'bath toy organizer',
#    'timestamp': Timestamp('2019-11-01 19:02:01.551000')},
#   {'asin': u'B07KT6BM9Y',
#    'frequency': 1,
#    'key': 'TaZXYtggcD5dJMkekoc263',
#    'query': u'bath toy organizer',
#    'timestamp': Timestamp('2019-10-16 03:01:39.111000')}],
#  u'biotin': [{'asin': u'B009SZXM4E',
#    'frequency': 1,
#    'key': 'FKZJFxAmvvfWNa4E7aFzoh',
#    'query': u'biotin',
#    'timestamp': Timestamp('2019-10-18 07:09:56.915000')},
#   {'asin': u'B00IOZWC2M',
#    'frequency': 1,
#    'key': 'gyRw8czMh4LLzBxdPJd2Si',
#    'query': u'biotin',
#    'timestamp': Timestamp('2019-10-18 07:10:09.525000')},
#   {'asin': u'B00T56FQAE',
#    'frequency': 1,
#    'key': '4Y77FXZPmTpnxmHGj3FJjj',
#    'query': u'biotin',
#    'timestamp': Timestamp('2019-10-18 07:10:15.039000')}],
#  u'carabiner clip': [{'asin': u'B013NNG18U',
#    'frequency': 57,
#    'key': '5GXurd6zjKy3FNCoviXHoj',
#    'query': u'carabiner clip',
#    'timestamp': Timestamp('2019-12-13 21:11:32.807000')},
#   {'asin': u'UNDEFINED',
#    'frequency': 47,
#    'key': 'DkTKSeoAviKwHftPhkYngJ',
#    'query': u'carabiner clip',
#    'timestamp': Timestamp('2019-12-03 19:23:52.759000')},
#   {'asin': u'B0719B4LNH',
#    'frequency': 37,
#    'key': 'b8rUFpe3RLPadSLvd5fNvW',
#    'query': u'carabiner clip',
#    'timestamp': Timestamp('2019-12-03 19:55:28.948000')},
#   {'asin': u'B07TT353XQ',
#    'frequency': 29,
#    'key': 'WsGWVYiGDa9Wf3Vn3R5ESH',
#    'query': u'carabiner clip',
#    'timestamp': Timestamp('2019-12-01 06:27:25.154000')},
#   {'asin': u'B07QH1YW88',
#    'frequency': 29,
#    'key': 'uVQ2Tj2m7ZhZcQcJ5PokVC',
#    'query': u'carabiner clip',
#    'timestamp': Timestamp('2019-12-04 01:33:24.729000')},
#   {'asin': u'B072NCYVQK',
#    'frequency': 25,
#    'key': '6rZSvjJuQ6VArhW3B5gpvW',
#    'query': u'carabiner clip',
#    'timestamp': Timestamp('2019-11-29 20:18:56.897000')},
#   {'asin': u'B07CWKGZYL',
#    'frequency': 19,
#    'key': 'kLwPPSW6K2HQqhHhyxyEeU',
#    'query': u'carabiner clip',
#    'timestamp': Timestamp('2019-10-16 03:04:58.480000')},
#   {'asin': u'B073GJ59QM',
#    'frequency': 16,
#    'key': 'aexwk7RJckGVFXFgjCwq4c',
#    'query': u'carabiner clip',
#    'timestamp': Timestamp('2019-12-03 19:55:40.611000')},
#   {'asin': u'B073DXLPZ9',
#    'frequency': 10,
#    'key': 'mmVYacPfTQ5BaK8km72fXL',
#    'query': u'carabiner clip',
#    'timestamp': Timestamp('2019-10-21 06:19:36.465000')},
#   {'asin': u'B07TV1TRDR',
#    'frequency': 6,
#    'key': 'WEepzdhygS395iLP5vsgXN',
#    'query': u'carabiner clip',
#    'timestamp': Timestamp('2019-11-27 19:24:36.278000')},
#   {'asin': u'B07JK9DYNR',
#    'frequency': 5,
#    'key': 'nHtmgZqYqE5JEjy3UraHPD',
#    'query': u'carabiner clip',
#    'timestamp': Timestamp('2019-10-21 06:19:24.165000')},
#   {'asin': u'B07GQV8H5V',
#    'frequency': 5,
#    'key': 'fpjXARyNhnEiQCdi5SZCQo',
#    'query': u'carabiner clip',
#    'timestamp': Timestamp('2019-11-29 21:48:05.981000')},
#   {'asin': u'XYZ',
#    'frequency': 3,
#    'key': 'FD8WbYNHt6cVUXs3Q8xQbQ',
#    'query': u'carabiner clip',
#    'timestamp': Timestamp('2019-11-30 07:03:48.934000')},
#   {'asin': u'B07JJZTYSV',
#    'frequency': 2,
#    'key': 'vZnSTJ9X3qHWEM8dXJoCWL',
#    'query': u'carabiner clip',
#    'timestamp': Timestamp('2019-10-17 06:32:03.857000')},
#   {'asin': u'B07RFL8J76',
#    'frequency': 2,
#    'key': '2KiodrgdzGqYjWRMFJL6Vj',
#    'query': u'carabiner clip',
#    'timestamp': Timestamp('2019-11-01 18:59:15.915000')},
#   {'asin': u'B07SZ4VP91',
#    'frequency': 2,
#    'key': 'B7Cx9HT4aKR7HzMkUDM9yC',
#    'query': u'carabiner clip',
#    'timestamp': Timestamp('2019-11-02 06:30:33.385000')},
#   {'asin': u'B07DD9RQFF',
#    'frequency': 2,
#    'key': 'uGrWdiQrBiT5HWkYXm7jq7',
#    'query': u'carabiner clip',
#    'timestamp': Timestamp('2019-11-02 06:30:48.428000')},
#   {'asin': u'0525568077',
#    'frequency': 1,
#    'key': 'G8VFU9QePM98hf7ijhFeCn',
#    'query': u'carabiner clip',
#    'timestamp': Timestamp('2019-10-16 03:05:27.938000')}],
#  u'coloring book': [{'asin': u'1945710799',
#    'frequency': 5,
#    'key': 'zdi93LeGfPKAaQSoYs8PkV',
#    'query': u'coloring book',
#    'timestamp': Timestamp('2019-10-16 01:03:25.422000')},
#   {'asin': u'B07MJ7N6VW',
#    'frequency': 3,
#    'key': 'rZ2yaN3rhtMTUXFs5mnTED',
#    'query': u'coloring book',
#    'timestamp': Timestamp('2019-12-04 07:12:21.880000')},
#   {'asin': u'1999896963',
#    'frequency': 2,
#    'key': 'CyX8GKNU6Y2kNh4wJvtkAf',
#    'query': u'coloring book',
#    'timestamp': Timestamp('2019-10-11 04:23:16.319000')},
#   {'asin': u'0692927999',
#    'frequency': 1,
#    'key': 'L4grc8oZwu2AhJy2o3gHWa',
#    'query': u'coloring book',
#    'timestamp': Timestamp('2019-10-11 04:22:45.452000')}],
#  u'emergency lantern': [{'asin': u'B01C5QSENQ',
#    'frequency': 5,
#    'key': 'hBkD5W7xYgNVgKH3dDmgiF',
#    'query': u'emergency lantern',
#    'timestamp': Timestamp('2019-10-16 03:15:39.947000')},
#   {'asin': u'B07RMKR1GB',
#    'frequency': 1,
#    'key': 'Ld24AaWev3qwyFN3eSUyZ2',
#    'query': u'emergency lantern',
#    'timestamp': Timestamp('2019-10-15 02:09:52.408000')},
#   {'asin': u'B018L2WM86',
#    'frequency': 1,
#    'key': 'ZwZpGWsQH2SeZyHSvs4HrV',
#    'query': u'emergency lantern',
#    'timestamp': Timestamp('2019-10-16 03:04:29.880000')},
#   {'asin': u'B00NPLSZF8',
#    'frequency': 1,
#    'key': 'a2ao6MJQBRH5ZetSkmKMEB',
#    'query': u'emergency lantern',
#    'timestamp': Timestamp('2019-10-16 03:15:46.062000')}],
#  u'outdoor dog fence system': [{'asin': u'B07X9962NK',
#    'frequency': 2,
#    'key': 'nu6XhYPZYAcvQehPP5ubtY',
#    'query': u'outdoor dog fence system',
#    'timestamp': Timestamp('2019-10-14 19:05:31.398000')},
#   {'asin': u'B07RFD9P55',
#    'frequency': 2,
#    'key': 'XGfvbMB75ZtCA5aYq8gQT2',
#    'query': u'outdoor dog fence system',
#    'timestamp': Timestamp('2019-10-19 08:19:48.839000')},
#   {'asin': u'0071357807',
#    'frequency': 2,
#    'key': 'pbVDgQKZixxPKi9DQUZVcj',
#    'query': u'outdoor dog fence system',
#    'timestamp': Timestamp('2019-12-03 07:08:28.939000')},
#   {'asin': u'UNDEFINED',
#    'frequency': 2,
#    'key': 'dDMmBHZmupmy6VrunGiBJ6',
#    'query': u'outdoor dog fence system',
#    'timestamp': Timestamp('2019-12-03 09:28:29.691000')},
#   {'asin': u'B07W1KDNRV',
#    'frequency': 1,
#    'key': 'JKWywnNPFsSdfq83XtMaHb',
#    'query': u'outdoor dog fence system',
#    'timestamp': Timestamp('2019-10-16 01:03:21.038000')},
#   {'asin': u'B07DNHV7X9',
#    'frequency': 1,
#    'key': 'gk32QoaEwZeumGPUr2CGYD',
#    'query': u'outdoor dog fence system',
#    'timestamp': Timestamp('2019-10-19 08:19:08.376000')},
#   {'asin': u'B0001ZWZ8O',
#    'frequency': 1,
#    'key': 'Z7aNboQ8DL9V43FyoxnaLo',
#    'query': u'outdoor dog fence system',
#    'timestamp': Timestamp('2019-10-19 08:19:42.704000')},
#   {'asin': u'0071774351',
#    'frequency': 1,
#    'key': 'ZWqCPVYdij5U6PqQiBcy82',
#    'query': u'outdoor dog fence system',
#    'timestamp': Timestamp('2019-12-03 06:52:51.296000')}],
#  u'toys for little brothers': [{'asin': u'B06W9NCZYX',
#    'frequency': 1,
#    'key': 'UEX5crJ5HYhfFytQ8DkjnT',
#    'query': u'toys for little brothers',
#    'timestamp': Timestamp('2019-10-16 03:52:11.769000')},
#   {'asin': u'B076ZVX8TM',
#    'frequency': 1,
#    'key': 'WLS8tkSFofWx7Tdmtoc4kH',
#    'query': u'toys for little brothers',
#    'timestamp': Timestamp('2019-10-16 03:52:28.495000')}],
#  u'weather proof furniture': [{'asin': u'B07VC529JB',
#    'frequency': 3,
#    'key': '6ab8B8y7BTjEdrhRwN33EU',
#    'query': u'weather proof furniture',
#    'timestamp': Timestamp('2019-10-18 19:50:44.161000')},
#   {'asin': u'B00ZTNK8FA',
#    'frequency': 1,
#    'key': 'RnRuCtyHqJwGY7LZCHJh7T',
#    'query': u'weather proof furniture',
#    'timestamp': Timestamp('2019-10-16 03:55:16.847000')},
#   {'asin': u'B016MAVG86',
#    'frequency': 1,
#    'key': 'g8awJjkeHrakJCBzXPAsRX',
#    'query': u'weather proof furniture',
#    'timestamp': Timestamp('2019-10-16 03:55:48.929000')},
#   {'asin': u'B07VH4GK85',
#    'frequency': 1,
#    'key': 'gzjLwawo8EKUTBBqpnQ9DW',
#    'query': u'weather proof furniture',
#    'timestamp': Timestamp('2019-10-16 04:04:01.100000')}]}

# %%
#reports_df.groupby(['query']).agg({'frequency': 'sum', 'timestamp': 'last'}).reset_index().to_dict(orient='records')

reports_df.groupby(['asin']).agg({'frequency': 'sum', 'timestamp': 'last', 'query': [('size', 'count')]}).reset_index().sort_values(by=['timestamp'], ascending=[False]).to_dict(orient='records')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-0befbf8be211> in <module>()
#       1 #reports_df.groupby(['query']).agg({'frequency': 'sum', 'timestamp': 'last'}).reset_index().to_dict(orient='records')
#       2
# ----> 3 reports_df.groupby(['asin']).agg({'frequency': 'sum', 'timestamp': 'last', 'query': [('size', 'count')]}).reset_index().sort_values(by=['timestamp'], ascending=[False]).to_dict(orient='records')
#
# /Users/evgenyp/Projects/AmzJet/AmzJet/amz-deploy/dev/.venv-dev/lib/python2.7/site-packages/pandas/core/frame.pyc in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4717
#    4718             by = by[0]
# -> 4719             k = self._get_label_or_level_values(by, axis=axis)
#    4720
#    4721             if isinstance(ascending, (tuple, list)):
#
# /Users/evgenyp/Projects/AmzJet/AmzJet/amz-deploy/dev/.venv-dev/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_label_or_level_values(self, key, axis)
#    1723                              .format(key=key,
#    1724                                      label_axis_name=label_axis_name,
# -> 1725                                      multi_message=multi_message))
#    1726
#    1727         return values
#
# ValueError: The column label 'timestamp' is not unique.
# For a multi-index, the label must be a tuple with elements corresponding to each level.

# %%
SAMPLE_QUERY_WHITELIST = ['carabiner clip']

def get_searched_queries(mongo_db, user_id):
    utc_time_now = utc_time()

    cursor = search_artifact.coll(mongo_db).find({
        'user_id':
        user_id,
        'type_id':
        search_artifact.TYPE_ID
    }).sort([('modified_at', -1)])

    results = []
    queries_in_results = set()

    for item in cursor:
        artifact_updater.apply_timeouts_to_state(item, utc_time_now)
        record = {
            'query': item['key']['query'] if 'key' in item else item['instance_id'],            
            'created_at': item['created_at'],
            'modified_at': item['modified_at'],
            'action_id': item['update']['action_id'],
            'action_done': item['update']['done'],
            'action_success': item['update'].get('success'),
            'updates_succeeded': item['stat'].get('updates_succeeded') if 'stat' in item else None,
            'avg_state_var': item['meta'].get('avg_state_var') if 'meta' in item else None            
        }
        results.append(record)
        queries_in_results.add(record['query'])

    injected_results = []
    for sample_query in SAMPLE_QUERY_WHITELIST:
        if sample_query not in queries_in_results:
            injected_results.append({
                'is_sample': True,
                'query': sample_query,
                'action_done': True,
                'action_success': True
            })

    return injected_results + results

get_searched_queries(mongo_db, user_id)

# %%
import flask
import pandas as pd
import pymongo
from flask_classful import FlaskView
from flask_jwt_extended import jwt_required

import amz_local_search.artifacts.search as search_artifact
from amz_local_search.base.instances import artifact_updater
from amz_local_search.config import get_config
from bb_utils.time.utils import utc_time
from bb_utils.utils.mmh3_hash import json_to_hash128_s
from web_app_api.extensions import get_user_id_from_jwt


def connect_to_mongo_db():
    mongo_uri = get_config().mongo_local_search_db_uri()
    client = pymongo.MongoClient(mongo_uri)
    return client.get_database()


SAMPLE_QUERY_WHITELIST = ['carabiner clip']


class Catalog(FlaskView):
    route_prefix = 'api/local-search/query'

    def get_asins_meta(self, mongo_db, asins):
        product_details = dict(
            (p['asin'], p)
            for p in mongo_db.products.find({'_id': {
                '$in': asins
            }}))
        return product_details

    def asin_report_key(self, query, asin):
        return json_to_hash128_s([query, asin])

    def get_asin_reports_from_actions(self, mongo_db, user_id,
                                      scan_depth=1000):
        matches = mongo_db.actions.find(
            {
                'user.id': user_id,
                'action_sig': 'amz_local_search.report(query, asin)',
                'state.success': True,
                'args.asin': {
                    '$nin': ['@latest', '@LATEST']
                }
            }, {
                'args.asin': 1,
                'args.query': 1,
                'occurred_at': 1
            }).sort([('occurred_at', -1)]).limit(scan_depth)

        reports = {}
        for match in matches:
            asin = match['args'].get('asin', '').strip()
            query = match['args'].get('query', '').strip()

            if not asin or asin.startswith('@'):
                continue

            key = self.asin_report_key(query, asin)

            report = reports.get(key)
            if report:
                report['frequency'] = report['frequency'] + 1
            else:
                reports[key] = {
                    'key': key,
                    'query': query,
                    'asin': asin,
                    'timestamp': match['occurred_at'],
                    'frequency': 1
                }
        return reports

    def get_searched_queries_from_artifacts(self, mongo_db, user_id):
        utc_time_now = utc_time()

        cursor = search_artifact.coll(mongo_db).find({
            'user_id':
            user_id,
            'type_id':
            search_artifact.TYPE_ID
        }).sort([('modified_at', -1)])

        results = []
        queries_in_results = set()

        for item in cursor:
            artifact_updater.apply_timeouts_to_state(item, utc_time_now)
            record = {
                'query':
                item['key']['query'] if 'key' in item else item['instance_id'],
                'created_at':
                item['created_at'],
                'modified_at':
                item['modified_at'],
                'action_id':
                item['update']['action_id'],
                'action_done':
                item['update']['done'],
                'action_success':
                item['update'].get('success'),
                'updates_succeeded':
                item['stat'].get('updates_succeeded')
                if 'stat' in item else None,
                'avg_state_var':
                item['meta'].get('avg_state_var') if 'meta' in item else None
            }
            results.append(record)
            queries_in_results.add(record['query'])

        injected_results = []
        for sample_query in SAMPLE_QUERY_WHITELIST:
            if sample_query not in queries_in_results:
                injected_results.append({
                    'is_sample': True,
                    'query': sample_query,
                    'action_done': True,
                    'action_success': True
                })

        return injected_results + results

    def get_view_for_asins(self, asin_reports_df):
        result = {}

        by_asin = asin_reports_df.groupby(['asin'])

        def group_to_sorted_records(g):
            sorted_g = g.sort_values(by=['timestamp', 'frequency'],
                                     ascending=[False, True])
            return sorted_g.to_dict(orient='records')

        result['groups'] = by_asin.apply(group_to_sorted_records).to_dict()

        agg_asins = by_asin.agg({
            'frequency': 'sum',
            'timestamp': 'last',
            'query': 'count'
        })
        result['keys'] = agg_asins.reset_index().sort_values(
            by=['timestamp'], ascending=[False]).to_dict(orient='records')

        return result

    def get_view_for_queries(self, mongo_db, user_id, asin_reports_df):
        result = {}

        by_query = asin_reports_df.groupby(['query'])

        def group_to_sorted_records(g):
            sorted_g = g.sort_values(by=['timestamp', 'frequency'],
                                     ascending=[False, True])
            return sorted_g.to_dict(orient='records')

        result['groups'] = by_query.apply(group_to_sorted_records).to_dict()

        result['keys'] = self.get_searched_queries_from_artifacts(mongo_db, user_id)

        return result


    def index(self):
        user_id = 1

        result = {}

        mongo_db = connect_to_mongo_db()

        asin_reports_dict = self.get_asin_reports_from_actions(
            mongo_db, user_id)
        asin_reports_df = pd.DataFrame(asin_reports_dict.values())

        result['by_asins'] = self.get_view_for_asins(asin_reports_df)

        result['by_queries'] = self.get_view_for_queries(
            mongo_db, user_id, asin_reports_df)
        return result

Catalog().index()
# Out:
# {'by_asins': {'groups': {u'0071357807': [{'asin': u'0071357807',
#      'frequency': 2,
#      'key': 'pbVDgQKZixxPKi9DQUZVcj',
#      'query': u'outdoor dog fence system',
#      'timestamp': Timestamp('2019-12-03 07:08:28.939000')}],
#    u'0071774351': [{'asin': u'0071774351',
#      'frequency': 1,
#      'key': 'ZWqCPVYdij5U6PqQiBcy82',
#      'query': u'outdoor dog fence system',
#      'timestamp': Timestamp('2019-12-03 06:52:51.296000')}],
#    u'0525568077': [{'asin': u'0525568077',
#      'frequency': 1,
#      'key': 'G8VFU9QePM98hf7ijhFeCn',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-10-16 03:05:27.938000')}],
#    u'0692927999': [{'asin': u'0692927999',
#      'frequency': 1,
#      'key': 'L4grc8oZwu2AhJy2o3gHWa',
#      'query': u'coloring book',
#      'timestamp': Timestamp('2019-10-11 04:22:45.452000')}],
#    u'1945710799': [{'asin': u'1945710799',
#      'frequency': 5,
#      'key': 'zdi93LeGfPKAaQSoYs8PkV',
#      'query': u'coloring book',
#      'timestamp': Timestamp('2019-10-16 01:03:25.422000')}],
#    u'1999896963': [{'asin': u'1999896963',
#      'frequency': 2,
#      'key': 'CyX8GKNU6Y2kNh4wJvtkAf',
#      'query': u'coloring book',
#      'timestamp': Timestamp('2019-10-11 04:23:16.319000')}],
#    u'B0001ZWZ8O': [{'asin': u'B0001ZWZ8O',
#      'frequency': 1,
#      'key': 'Z7aNboQ8DL9V43FyoxnaLo',
#      'query': u'outdoor dog fence system',
#      'timestamp': Timestamp('2019-10-19 08:19:42.704000')}],
#    u'B000MVQBG4': [{'asin': u'B000MVQBG4',
#      'frequency': 3,
#      'key': 'B9j9SSSg4nDswY9w74GN5e',
#      'query': u'bath toy organizer',
#      'timestamp': Timestamp('2019-11-01 19:02:18.533000')}],
#    u'B006SFUDT4': [{'asin': u'B006SFUDT4',
#      'frequency': 2,
#      'key': '55WckJx2QMN3amjM63iwye',
#      'query': u'bath toy organizer',
#      'timestamp': Timestamp('2019-11-01 19:02:01.551000')}],
#    u'B009SZXM4E': [{'asin': u'B009SZXM4E',
#      'frequency': 1,
#      'key': 'FKZJFxAmvvfWNa4E7aFzoh',
#      'query': u'biotin',
#      'timestamp': Timestamp('2019-10-18 07:09:56.915000')}],
#    u'B00IOZWC2M': [{'asin': u'B00IOZWC2M',
#      'frequency': 1,
#      'key': 'gyRw8czMh4LLzBxdPJd2Si',
#      'query': u'biotin',
#      'timestamp': Timestamp('2019-10-18 07:10:09.525000')}],
#    u'B00NPLSZF8': [{'asin': u'B00NPLSZF8',
#      'frequency': 1,
#      'key': 'a2ao6MJQBRH5ZetSkmKMEB',
#      'query': u'emergency lantern',
#      'timestamp': Timestamp('2019-10-16 03:15:46.062000')}],
#    u'B00T56FQAE': [{'asin': u'B00T56FQAE',
#      'frequency': 1,
#      'key': '4Y77FXZPmTpnxmHGj3FJjj',
#      'query': u'biotin',
#      'timestamp': Timestamp('2019-10-18 07:10:15.039000')}],
#    u'B00ZTNK8FA': [{'asin': u'B00ZTNK8FA',
#      'frequency': 1,
#      'key': 'RnRuCtyHqJwGY7LZCHJh7T',
#      'query': u'weather proof furniture',
#      'timestamp': Timestamp('2019-10-16 03:55:16.847000')}],
#    u'B013NNG18U': [{'asin': u'B013NNG18U',
#      'frequency': 57,
#      'key': '5GXurd6zjKy3FNCoviXHoj',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-12-13 21:11:32.807000')}],
#    u'B016MAVG86': [{'asin': u'B016MAVG86',
#      'frequency': 1,
#      'key': 'g8awJjkeHrakJCBzXPAsRX',
#      'query': u'weather proof furniture',
#      'timestamp': Timestamp('2019-10-16 03:55:48.929000')}],
#    u'B018L2WM86': [{'asin': u'B018L2WM86',
#      'frequency': 1,
#      'key': 'ZwZpGWsQH2SeZyHSvs4HrV',
#      'query': u'emergency lantern',
#      'timestamp': Timestamp('2019-10-16 03:04:29.880000')}],
#    u'B01C5QSENQ': [{'asin': u'B01C5QSENQ',
#      'frequency': 5,
#      'key': 'hBkD5W7xYgNVgKH3dDmgiF',
#      'query': u'emergency lantern',
#      'timestamp': Timestamp('2019-10-16 03:15:39.947000')}],
#    u'B01DAPMQO4': [{'asin': u'B01DAPMQO4',
#      'frequency': 3,
#      'key': 'brSeE5xBXw8gEV2PQfAUnX',
#      'query': u'bath toy organizer',
#      'timestamp': Timestamp('2019-11-01 19:02:11.320000')}],
#    u'B01M6ZFU02': [{'asin': u'B01M6ZFU02',
#      'frequency': 9,
#      'key': 'B8LnPiTUYEaLsYxLYHrQxL',
#      'query': u'bath toy organizer',
#      'timestamp': Timestamp('2019-10-16 03:00:49.222000')}],
#    u'B06W9NCZYX': [{'asin': u'B06W9NCZYX',
#      'frequency': 1,
#      'key': 'UEX5crJ5HYhfFytQ8DkjnT',
#      'query': u'toys for little brothers',
#      'timestamp': Timestamp('2019-10-16 03:52:11.769000')}],
#    u'B0719B4LNH': [{'asin': u'B0719B4LNH',
#      'frequency': 37,
#      'key': 'b8rUFpe3RLPadSLvd5fNvW',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-12-03 19:55:28.948000')}],
#    u'B072NCYVQK': [{'asin': u'B072NCYVQK',
#      'frequency': 25,
#      'key': '6rZSvjJuQ6VArhW3B5gpvW',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-11-29 20:18:56.897000')}],
#    u'B073DXLPZ9': [{'asin': u'B073DXLPZ9',
#      'frequency': 10,
#      'key': 'mmVYacPfTQ5BaK8km72fXL',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-10-21 06:19:36.465000')}],
#    u'B073GJ59QM': [{'asin': u'B073GJ59QM',
#      'frequency': 16,
#      'key': 'aexwk7RJckGVFXFgjCwq4c',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-12-03 19:55:40.611000')}],
#    u'B076ZVX8TM': [{'asin': u'B076ZVX8TM',
#      'frequency': 1,
#      'key': 'WLS8tkSFofWx7Tdmtoc4kH',
#      'query': u'toys for little brothers',
#      'timestamp': Timestamp('2019-10-16 03:52:28.495000')}],
#    u'B077YNNT54': [{'asin': u'B077YNNT54',
#      'frequency': 3,
#      'key': 'tWT2D2wnPbDr6g2Frwo2LB',
#      'query': u'bath toy organizer',
#      'timestamp': Timestamp('2019-10-16 02:57:31.588000')}],
#    u'B07CWKGZYL': [{'asin': u'B07CWKGZYL',
#      'frequency': 19,
#      'key': 'kLwPPSW6K2HQqhHhyxyEeU',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-10-16 03:04:58.480000')}],
#    u'B07DD9RQFF': [{'asin': u'B07DD9RQFF',
#      'frequency': 2,
#      'key': 'uGrWdiQrBiT5HWkYXm7jq7',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-11-02 06:30:48.428000')},
#     {'asin': u'B07DD9RQFF',
#      'frequency': 1,
#      'key': '4Krb38NF5JXtqPvV2NDkUC',
#      'query': u'b07dd9rqff',
#      'timestamp': Timestamp('2019-10-17 05:24:28.518000')}],
#    u'B07DNHV7X9': [{'asin': u'B07DNHV7X9',
#      'frequency': 1,
#      'key': 'gk32QoaEwZeumGPUr2CGYD',
#      'query': u'outdoor dog fence system',
#      'timestamp': Timestamp('2019-10-19 08:19:08.376000')}],
#    u'B07GQV8H5V': [{'asin': u'B07GQV8H5V',
#      'frequency': 5,
#      'key': 'fpjXARyNhnEiQCdi5SZCQo',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-11-29 21:48:05.981000')}],
#    u'B07JJZTYSV': [{'asin': u'B07JJZTYSV',
#      'frequency': 2,
#      'key': 'vZnSTJ9X3qHWEM8dXJoCWL',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-10-17 06:32:03.857000')}],
#    u'B07JK9DYNR': [{'asin': u'B07JK9DYNR',
#      'frequency': 5,
#      'key': 'nHtmgZqYqE5JEjy3UraHPD',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-10-21 06:19:24.165000')}],
#    u'B07KT6BM9Y': [{'asin': u'B07KT6BM9Y',
#      'frequency': 1,
#      'key': 'TaZXYtggcD5dJMkekoc263',
#      'query': u'bath toy organizer',
#      'timestamp': Timestamp('2019-10-16 03:01:39.111000')}],
#    u'B07MJ7N6VW': [{'asin': u'B07MJ7N6VW',
#      'frequency': 3,
#      'key': 'rZ2yaN3rhtMTUXFs5mnTED',
#      'query': u'coloring book',
#      'timestamp': Timestamp('2019-12-04 07:12:21.880000')}],
#    u'B07QH1YW88': [{'asin': u'B07QH1YW88',
#      'frequency': 29,
#      'key': 'uVQ2Tj2m7ZhZcQcJ5PokVC',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-12-04 01:33:24.729000')}],
#    u'B07RFD9P55': [{'asin': u'B07RFD9P55',
#      'frequency': 2,
#      'key': 'XGfvbMB75ZtCA5aYq8gQT2',
#      'query': u'outdoor dog fence system',
#      'timestamp': Timestamp('2019-10-19 08:19:48.839000')}],
#    u'B07RFL8J76': [{'asin': u'B07RFL8J76',
#      'frequency': 2,
#      'key': '2KiodrgdzGqYjWRMFJL6Vj',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-11-01 18:59:15.915000')}],
#    u'B07RMKR1GB': [{'asin': u'B07RMKR1GB',
#      'frequency': 1,
#      'key': 'Ld24AaWev3qwyFN3eSUyZ2',
#      'query': u'emergency lantern',
#      'timestamp': Timestamp('2019-10-15 02:09:52.408000')}],
#    u'B07SZ4VP91': [{'asin': u'B07SZ4VP91',
#      'frequency': 2,
#      'key': 'B7Cx9HT4aKR7HzMkUDM9yC',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-11-02 06:30:33.385000')}],
#    u'B07TT353XQ': [{'asin': u'B07TT353XQ',
#      'frequency': 29,
#      'key': 'WsGWVYiGDa9Wf3Vn3R5ESH',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-12-01 06:27:25.154000')}],
#    u'B07TV1TRDR': [{'asin': u'B07TV1TRDR',
#      'frequency': 6,
#      'key': 'WEepzdhygS395iLP5vsgXN',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-11-27 19:24:36.278000')}],
#    u'B07VC529JB': [{'asin': u'B07VC529JB',
#      'frequency': 3,
#      'key': '6ab8B8y7BTjEdrhRwN33EU',
#      'query': u'weather proof furniture',
#      'timestamp': Timestamp('2019-10-18 19:50:44.161000')}],
#    u'B07VH4GK85': [{'asin': u'B07VH4GK85',
#      'frequency': 1,
#      'key': 'gzjLwawo8EKUTBBqpnQ9DW',
#      'query': u'weather proof furniture',
#      'timestamp': Timestamp('2019-10-16 04:04:01.100000')}],
#    u'B07W1KDNRV': [{'asin': u'B07W1KDNRV',
#      'frequency': 1,
#      'key': 'JKWywnNPFsSdfq83XtMaHb',
#      'query': u'outdoor dog fence system',
#      'timestamp': Timestamp('2019-10-16 01:03:21.038000')}],
#    u'B07X9962NK': [{'asin': u'B07X9962NK',
#      'frequency': 2,
#      'key': 'nu6XhYPZYAcvQehPP5ubtY',
#      'query': u'outdoor dog fence system',
#      'timestamp': Timestamp('2019-10-14 19:05:31.398000')}],
#    u'UNDEFINED': [{'asin': u'UNDEFINED',
#      'frequency': 47,
#      'key': 'DkTKSeoAviKwHftPhkYngJ',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-12-03 19:23:52.759000')},
#     {'asin': u'UNDEFINED',
#      'frequency': 2,
#      'key': 'dDMmBHZmupmy6VrunGiBJ6',
#      'query': u'outdoor dog fence system',
#      'timestamp': Timestamp('2019-12-03 09:28:29.691000')}],
#    u'XYZ': [{'asin': u'XYZ',
#      'frequency': 3,
#      'key': 'FD8WbYNHt6cVUXs3Q8xQbQ',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-11-30 07:03:48.934000')}]},
#   'keys': [{'asin': u'B013NNG18U',
#     'frequency': 57,
#     'query': 1,
#     'timestamp': Timestamp('2019-12-13 21:11:32.807000')},
#    {'asin': u'B07MJ7N6VW',
#     'frequency': 3,
#     'query': 1,
#     'timestamp': Timestamp('2019-12-04 07:12:21.880000')},
#    {'asin': u'B07QH1YW88',
#     'frequency': 29,
#     'query': 1,
#     'timestamp': Timestamp('2019-12-04 01:33:24.729000')},
#    {'asin': u'B073GJ59QM',
#     'frequency': 16,
#     'query': 1,
#     'timestamp': Timestamp('2019-12-03 19:55:40.611000')},
#    {'asin': u'B0719B4LNH',
#     'frequency': 37,
#     'query': 1,
#     'timestamp': Timestamp('2019-12-03 19:55:28.948000')},
#    {'asin': u'UNDEFINED',
#     'frequency': 49,
#     'query': 2,
#     'timestamp': Timestamp('2019-12-03 19:23:52.759000')},
#    {'asin': u'0071357807',
#     'frequency': 2,
#     'query': 1,
#     'timestamp': Timestamp('2019-12-03 07:08:28.939000')},
#    {'asin': u'0071774351',
#     'frequency': 1,
#     'query': 1,
#     'timestamp': Timestamp('2019-12-03 06:52:51.296000')},
#    {'asin': u'B07TT353XQ',
#     'frequency': 29,
#     'query': 1,
#     'timestamp': Timestamp('2019-12-01 06:27:25.154000')},
#    {'asin': u'XYZ',
#     'frequency': 3,
#     'query': 1,
#     'timestamp': Timestamp('2019-11-30 07:03:48.934000')},
#    {'asin': u'B07GQV8H5V',
#     'frequency': 5,
#     'query': 1,
#     'timestamp': Timestamp('2019-11-29 21:48:05.981000')},
#    {'asin': u'B072NCYVQK',
#     'frequency': 25,
#     'query': 1,
#     'timestamp': Timestamp('2019-11-29 20:18:56.897000')},
#    {'asin': u'B07TV1TRDR',
#     'frequency': 6,
#     'query': 1,
#     'timestamp': Timestamp('2019-11-27 19:24:36.278000')},
#    {'asin': u'B07DD9RQFF',
#     'frequency': 3,
#     'query': 2,
#     'timestamp': Timestamp('2019-11-02 06:30:48.428000')},
#    {'asin': u'B07SZ4VP91',
#     'frequency': 2,
#     'query': 1,
#     'timestamp': Timestamp('2019-11-02 06:30:33.385000')},
#    {'asin': u'B000MVQBG4',
#     'frequency': 3,
#     'query': 1,
#     'timestamp': Timestamp('2019-11-01 19:02:18.533000')},
#    {'asin': u'B01DAPMQO4',
#     'frequency': 3,
#     'query': 1,
#     'timestamp': Timestamp('2019-11-01 19:02:11.320000')},
#    {'asin': u'B006SFUDT4',
#     'frequency': 2,
#     'query': 1,
#     'timestamp': Timestamp('2019-11-01 19:02:01.551000')},
#    {'asin': u'B07RFL8J76',
#     'frequency': 2,
#     'query': 1,
#     'timestamp': Timestamp('2019-11-01 18:59:15.915000')},
#    {'asin': u'B073DXLPZ9',
#     'frequency': 10,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-21 06:19:36.465000')},
#    {'asin': u'B07JK9DYNR',
#     'frequency': 5,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-21 06:19:24.165000')},
#    {'asin': u'B07RFD9P55',
#     'frequency': 2,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-19 08:19:48.839000')},
#    {'asin': u'B0001ZWZ8O',
#     'frequency': 1,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-19 08:19:42.704000')},
#    {'asin': u'B07DNHV7X9',
#     'frequency': 1,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-19 08:19:08.376000')},
#    {'asin': u'B07VC529JB',
#     'frequency': 3,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-18 19:50:44.161000')},
#    {'asin': u'B00T56FQAE',
#     'frequency': 1,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-18 07:10:15.039000')},
#    {'asin': u'B00IOZWC2M',
#     'frequency': 1,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-18 07:10:09.525000')},
#    {'asin': u'B009SZXM4E',
#     'frequency': 1,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-18 07:09:56.915000')},
#    {'asin': u'B07JJZTYSV',
#     'frequency': 2,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-17 06:32:03.857000')},
#    {'asin': u'B07VH4GK85',
#     'frequency': 1,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-16 04:04:01.100000')},
#    {'asin': u'B016MAVG86',
#     'frequency': 1,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-16 03:55:48.929000')},
#    {'asin': u'B00ZTNK8FA',
#     'frequency': 1,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-16 03:55:16.847000')},
#    {'asin': u'B076ZVX8TM',
#     'frequency': 1,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-16 03:52:28.495000')},
#    {'asin': u'B06W9NCZYX',
#     'frequency': 1,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-16 03:52:11.769000')},
#    {'asin': u'B00NPLSZF8',
#     'frequency': 1,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-16 03:15:46.062000')},
#    {'asin': u'B01C5QSENQ',
#     'frequency': 5,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-16 03:15:39.947000')},
#    {'asin': u'0525568077',
#     'frequency': 1,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-16 03:05:27.938000')},
#    {'asin': u'B07CWKGZYL',
#     'frequency': 19,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-16 03:04:58.480000')},
#    {'asin': u'B018L2WM86',
#     'frequency': 1,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-16 03:04:29.880000')},
#    {'asin': u'B07KT6BM9Y',
#     'frequency': 1,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-16 03:01:39.111000')},
#    {'asin': u'B01M6ZFU02',
#     'frequency': 9,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-16 03:00:49.222000')},
#    {'asin': u'B077YNNT54',
#     'frequency': 3,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-16 02:57:31.588000')},
#    {'asin': u'1945710799',
#     'frequency': 5,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-16 01:03:25.422000')},
#    {'asin': u'B07W1KDNRV',
#     'frequency': 1,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-16 01:03:21.038000')},
#    {'asin': u'B07RMKR1GB',
#     'frequency': 1,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-15 02:09:52.408000')},
#    {'asin': u'B07X9962NK',
#     'frequency': 2,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-14 19:05:31.398000')},
#    {'asin': u'1999896963',
#     'frequency': 2,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-11 04:23:16.319000')},
#    {'asin': u'0692927999',
#     'frequency': 1,
#     'query': 1,
#     'timestamp': Timestamp('2019-10-11 04:22:45.452000')}]},
#  'by_queries': {'groups': {u'b07dd9rqff': [{'asin': u'B07DD9RQFF',
#      'frequency': 1,
#      'key': '4Krb38NF5JXtqPvV2NDkUC',
#      'query': u'b07dd9rqff',
#      'timestamp': Timestamp('2019-10-17 05:24:28.518000')}],
#    u'bath toy organizer': [{'asin': u'B000MVQBG4',
#      'frequency': 3,
#      'key': 'B9j9SSSg4nDswY9w74GN5e',
#      'query': u'bath toy organizer',
#      'timestamp': Timestamp('2019-11-01 19:02:18.533000')},
#     {'asin': u'B01DAPMQO4',
#      'frequency': 3,
#      'key': 'brSeE5xBXw8gEV2PQfAUnX',
#      'query': u'bath toy organizer',
#      'timestamp': Timestamp('2019-11-01 19:02:11.320000')},
#     {'asin': u'B006SFUDT4',
#      'frequency': 2,
#      'key': '55WckJx2QMN3amjM63iwye',
#      'query': u'bath toy organizer',
#      'timestamp': Timestamp('2019-11-01 19:02:01.551000')},
#     {'asin': u'B07KT6BM9Y',
#      'frequency': 1,
#      'key': 'TaZXYtggcD5dJMkekoc263',
#      'query': u'bath toy organizer',
#      'timestamp': Timestamp('2019-10-16 03:01:39.111000')},
#     {'asin': u'B01M6ZFU02',
#      'frequency': 9,
#      'key': 'B8LnPiTUYEaLsYxLYHrQxL',
#      'query': u'bath toy organizer',
#      'timestamp': Timestamp('2019-10-16 03:00:49.222000')},
#     {'asin': u'B077YNNT54',
#      'frequency': 3,
#      'key': 'tWT2D2wnPbDr6g2Frwo2LB',
#      'query': u'bath toy organizer',
#      'timestamp': Timestamp('2019-10-16 02:57:31.588000')}],
#    u'biotin': [{'asin': u'B00T56FQAE',
#      'frequency': 1,
#      'key': '4Y77FXZPmTpnxmHGj3FJjj',
#      'query': u'biotin',
#      'timestamp': Timestamp('2019-10-18 07:10:15.039000')},
#     {'asin': u'B00IOZWC2M',
#      'frequency': 1,
#      'key': 'gyRw8czMh4LLzBxdPJd2Si',
#      'query': u'biotin',
#      'timestamp': Timestamp('2019-10-18 07:10:09.525000')},
#     {'asin': u'B009SZXM4E',
#      'frequency': 1,
#      'key': 'FKZJFxAmvvfWNa4E7aFzoh',
#      'query': u'biotin',
#      'timestamp': Timestamp('2019-10-18 07:09:56.915000')}],
#    u'carabiner clip': [{'asin': u'B013NNG18U',
#      'frequency': 57,
#      'key': '5GXurd6zjKy3FNCoviXHoj',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-12-13 21:11:32.807000')},
#     {'asin': u'B07QH1YW88',
#      'frequency': 29,
#      'key': 'uVQ2Tj2m7ZhZcQcJ5PokVC',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-12-04 01:33:24.729000')},
#     {'asin': u'B073GJ59QM',
#      'frequency': 16,
#      'key': 'aexwk7RJckGVFXFgjCwq4c',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-12-03 19:55:40.611000')},
#     {'asin': u'B0719B4LNH',
#      'frequency': 37,
#      'key': 'b8rUFpe3RLPadSLvd5fNvW',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-12-03 19:55:28.948000')},
#     {'asin': u'UNDEFINED',
#      'frequency': 47,
#      'key': 'DkTKSeoAviKwHftPhkYngJ',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-12-03 19:23:52.759000')},
#     {'asin': u'B07TT353XQ',
#      'frequency': 29,
#      'key': 'WsGWVYiGDa9Wf3Vn3R5ESH',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-12-01 06:27:25.154000')},
#     {'asin': u'XYZ',
#      'frequency': 3,
#      'key': 'FD8WbYNHt6cVUXs3Q8xQbQ',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-11-30 07:03:48.934000')},
#     {'asin': u'B07GQV8H5V',
#      'frequency': 5,
#      'key': 'fpjXARyNhnEiQCdi5SZCQo',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-11-29 21:48:05.981000')},
#     {'asin': u'B072NCYVQK',
#      'frequency': 25,
#      'key': '6rZSvjJuQ6VArhW3B5gpvW',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-11-29 20:18:56.897000')},
#     {'asin': u'B07TV1TRDR',
#      'frequency': 6,
#      'key': 'WEepzdhygS395iLP5vsgXN',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-11-27 19:24:36.278000')},
#     {'asin': u'B07DD9RQFF',
#      'frequency': 2,
#      'key': 'uGrWdiQrBiT5HWkYXm7jq7',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-11-02 06:30:48.428000')},
#     {'asin': u'B07SZ4VP91',
#      'frequency': 2,
#      'key': 'B7Cx9HT4aKR7HzMkUDM9yC',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-11-02 06:30:33.385000')},
#     {'asin': u'B07RFL8J76',
#      'frequency': 2,
#      'key': '2KiodrgdzGqYjWRMFJL6Vj',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-11-01 18:59:15.915000')},
#     {'asin': u'B073DXLPZ9',
#      'frequency': 10,
#      'key': 'mmVYacPfTQ5BaK8km72fXL',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-10-21 06:19:36.465000')},
#     {'asin': u'B07JK9DYNR',
#      'frequency': 5,
#      'key': 'nHtmgZqYqE5JEjy3UraHPD',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-10-21 06:19:24.165000')},
#     {'asin': u'B07JJZTYSV',
#      'frequency': 2,
#      'key': 'vZnSTJ9X3qHWEM8dXJoCWL',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-10-17 06:32:03.857000')},
#     {'asin': u'0525568077',
#      'frequency': 1,
#      'key': 'G8VFU9QePM98hf7ijhFeCn',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-10-16 03:05:27.938000')},
#     {'asin': u'B07CWKGZYL',
#      'frequency': 19,
#      'key': 'kLwPPSW6K2HQqhHhyxyEeU',
#      'query': u'carabiner clip',
#      'timestamp': Timestamp('2019-10-16 03:04:58.480000')}],
#    u'coloring book': [{'asin': u'B07MJ7N6VW',
#      'frequency': 3,
#      'key': 'rZ2yaN3rhtMTUXFs5mnTED',
#      'query': u'coloring book',
#      'timestamp': Timestamp('2019-12-04 07:12:21.880000')},
#     {'asin': u'1945710799',
#      'frequency': 5,
#      'key': 'zdi93LeGfPKAaQSoYs8PkV',
#      'query': u'coloring book',
#      'timestamp': Timestamp('2019-10-16 01:03:25.422000')},
#     {'asin': u'1999896963',
#      'frequency': 2,
#      'key': 'CyX8GKNU6Y2kNh4wJvtkAf',
#      'query': u'coloring book',
#      'timestamp': Timestamp('2019-10-11 04:23:16.319000')},
#     {'asin': u'0692927999',
#      'frequency': 1,
#      'key': 'L4grc8oZwu2AhJy2o3gHWa',
#      'query': u'coloring book',
#      'timestamp': Timestamp('2019-10-11 04:22:45.452000')}],
#    u'emergency lantern': [{'asin': u'B00NPLSZF8',
#      'frequency': 1,
#      'key': 'a2ao6MJQBRH5ZetSkmKMEB',
#      'query': u'emergency lantern',
#      'timestamp': Timestamp('2019-10-16 03:15:46.062000')},
#     {'asin': u'B01C5QSENQ',
#      'frequency': 5,
#      'key': 'hBkD5W7xYgNVgKH3dDmgiF',
#      'query': u'emergency lantern',
#      'timestamp': Timestamp('2019-10-16 03:15:39.947000')},
#     {'asin': u'B018L2WM86',
#      'frequency': 1,
#      'key': 'ZwZpGWsQH2SeZyHSvs4HrV',
#      'query': u'emergency lantern',
#      'timestamp': Timestamp('2019-10-16 03:04:29.880000')},
#     {'asin': u'B07RMKR1GB',
#      'frequency': 1,
#      'key': 'Ld24AaWev3qwyFN3eSUyZ2',
#      'query': u'emergency lantern',
#      'timestamp': Timestamp('2019-10-15 02:09:52.408000')}],
#    u'outdoor dog fence system': [{'asin': u'UNDEFINED',
#      'frequency': 2,
#      'key': 'dDMmBHZmupmy6VrunGiBJ6',
#      'query': u'outdoor dog fence system',
#      'timestamp': Timestamp('2019-12-03 09:28:29.691000')},
#     {'asin': u'0071357807',
#      'frequency': 2,
#      'key': 'pbVDgQKZixxPKi9DQUZVcj',
#      'query': u'outdoor dog fence system',
#      'timestamp': Timestamp('2019-12-03 07:08:28.939000')},
#     {'asin': u'0071774351',
#      'frequency': 1,
#      'key': 'ZWqCPVYdij5U6PqQiBcy82',
#      'query': u'outdoor dog fence system',
#      'timestamp': Timestamp('2019-12-03 06:52:51.296000')},
#     {'asin': u'B07RFD9P55',
#      'frequency': 2,
#      'key': 'XGfvbMB75ZtCA5aYq8gQT2',
#      'query': u'outdoor dog fence system',
#      'timestamp': Timestamp('2019-10-19 08:19:48.839000')},
#     {'asin': u'B0001ZWZ8O',
#      'frequency': 1,
#      'key': 'Z7aNboQ8DL9V43FyoxnaLo',
#      'query': u'outdoor dog fence system',
#      'timestamp': Timestamp('2019-10-19 08:19:42.704000')},
#     {'asin': u'B07DNHV7X9',
#      'frequency': 1,
#      'key': 'gk32QoaEwZeumGPUr2CGYD',
#      'query': u'outdoor dog fence system',
#      'timestamp': Timestamp('2019-10-19 08:19:08.376000')},
#     {'asin': u'B07W1KDNRV',
#      'frequency': 1,
#      'key': 'JKWywnNPFsSdfq83XtMaHb',
#      'query': u'outdoor dog fence system',
#      'timestamp': Timestamp('2019-10-16 01:03:21.038000')},
#     {'asin': u'B07X9962NK',
#      'frequency': 2,
#      'key': 'nu6XhYPZYAcvQehPP5ubtY',
#      'query': u'outdoor dog fence system',
#      'timestamp': Timestamp('2019-10-14 19:05:31.398000')}],
#    u'toys for little brothers': [{'asin': u'B076ZVX8TM',
#      'frequency': 1,
#      'key': 'WLS8tkSFofWx7Tdmtoc4kH',
#      'query': u'toys for little brothers',
#      'timestamp': Timestamp('2019-10-16 03:52:28.495000')},
#     {'asin': u'B06W9NCZYX',
#      'frequency': 1,
#      'key': 'UEX5crJ5HYhfFytQ8DkjnT',
#      'query': u'toys for little brothers',
#      'timestamp': Timestamp('2019-10-16 03:52:11.769000')}],
#    u'weather proof furniture': [{'asin': u'B07VC529JB',
#      'frequency': 3,
#      'key': '6ab8B8y7BTjEdrhRwN33EU',
#      'query': u'weather proof furniture',
#      'timestamp': Timestamp('2019-10-18 19:50:44.161000')},
#     {'asin': u'B07VH4GK85',
#      'frequency': 1,
#      'key': 'gzjLwawo8EKUTBBqpnQ9DW',
#      'query': u'weather proof furniture',
#      'timestamp': Timestamp('2019-10-16 04:04:01.100000')},
#     {'asin': u'B016MAVG86',
#      'frequency': 1,
#      'key': 'g8awJjkeHrakJCBzXPAsRX',
#      'query': u'weather proof furniture',
#      'timestamp': Timestamp('2019-10-16 03:55:48.929000')},
#     {'asin': u'B00ZTNK8FA',
#      'frequency': 1,
#      'key': 'RnRuCtyHqJwGY7LZCHJh7T',
#      'query': u'weather proof furniture',
#      'timestamp': Timestamp('2019-10-16 03:55:16.847000')}]},
#   'keys': [{'action_done': True,
#     'action_id': u'1-VT4d26Xsp6uNo7h7YHJo9S',
#     'action_success': True,
#     'avg_state_var': None,
#     'created_at': datetime.datetime(2019, 12, 13, 21, 25, 46, 421000),
#     'modified_at': datetime.datetime(2019, 12, 13, 21, 25, 53, 6000),
#     'query': u'test 427',
#     'updates_succeeded': 1},
#    {'action_done': True,
#     'action_id': u'1-jo8B7JenufXH7EaWwUNNVG',
#     'action_success': True,
#     'avg_state_var': None,
#     'created_at': datetime.datetime(2019, 12, 13, 21, 25, 29, 134000),
#     'modified_at': datetime.datetime(2019, 12, 13, 21, 25, 36, 751000),
#     'query': u'test 333',
#     'updates_succeeded': 1},
#    {'action_done': True,
#     'action_id': u'1-VB2TM7VFt6WaYJ9es53nFk',
#     'action_success': False,
#     'avg_state_var': None,
#     'created_at': datetime.datetime(2019, 12, 13, 21, 20, 39, 567000),
#     'modified_at': datetime.datetime(2019, 12, 13, 21, 20, 39, 567000),
#     'query': u'test 261',
#     'updates_succeeded': 0},
#    {'action_done': True,
#     'action_id': u'1-vAcdk5fJBH6sjURPE4ktQj',
#     'action_success': True,
#     'avg_state_var': None,
#     'created_at': datetime.datetime(2019, 12, 13, 21, 20, 3, 611000),
#     'modified_at': datetime.datetime(2019, 12, 13, 21, 20, 11, 643000),
#     'query': u'test 321',
#     'updates_succeeded': 1},
#    {'action_done': True,
#     'action_id': u'1-KDvvJe4G3xojCnFNi6LZGJ',
#     'action_success': False,
#     'avg_state_var': None,
#     'created_at': datetime.datetime(2019, 12, 13, 21, 16, 37, 337000),
#     'modified_at': datetime.datetime(2019, 12, 13, 21, 16, 37, 337000),
#     'query': u'test 1234',
#     'updates_succeeded': 0},
#    {'action_done': True,
#     'action_id': u'1-LiEH8DT45aW5dfNixmag2i',
#     'action_success': False,
#     'avg_state_var': None,
#     'created_at': datetime.datetime(2019, 12, 13, 21, 11, 54, 570000),
#     'modified_at': datetime.datetime(2019, 12, 13, 21, 11, 54, 570000),
#     'query': u'test 1111',
#     'updates_succeeded': 0},
#    {'action_done': True,
#     'action_id': u'1-E7egRhToE5B8GaYMFkqNsP',
#     'action_success': True,
#     'avg_state_var': None,
#     'created_at': datetime.datetime(2019, 12, 4, 1, 34, 27, 735000),
#     'modified_at': datetime.datetime(2019, 12, 4, 1, 34, 36, 490000),
#     'query': u'test keyword',
#     'updates_succeeded': 1},
#    {'action_done': True,
#     'action_id': u'1-rteJm2RzDfTHAjMguirqbc',
#     'action_success': True,
#     'avg_state_var': None,
#     'created_at': datetime.datetime(2019, 11, 29, 2, 1, 23, 761000),
#     'modified_at': datetime.datetime(2019, 11, 29, 2, 1, 35, 513000),
#     'query': u'zxtx',
#     'updates_succeeded': 1},
#    {'action_done': True,
#     'action_id': u'1-XwfwfmFKCzUoGFoZZPgbHQ',
#     'action_success': True,
#     'avg_state_var': None,
#     'created_at': datetime.datetime(2019, 11, 28, 22, 9, 42, 779000),
#     'modified_at': datetime.datetime(2019, 11, 28, 22, 9, 53, 457000),
#     'query': u'test 10',
#     'updates_succeeded': 1},
#    {'action_done': True,
#     'action_id': u'1-BB3XLskLKxx73MTzJVSeZJ',
#     'action_success': True,
#     'avg_state_var': 0.254873104257389,
#     'created_at': datetime.datetime(2019, 10, 9, 4, 23, 43, 985000),
#     'modified_at': datetime.datetime(2019, 11, 5, 6, 39, 53, 649000),
#     'query': u'carabiner clip',
#     'updates_succeeded': 46},
#    {'action_done': True,
#     'action_id': u'1-MoNgcMFXmSDAK3R4jbJptN',
#     'action_success': True,
#     'avg_state_var': 0.5123671309238333,
#     'created_at': datetime.datetime(2019, 10, 13, 19, 46, 43, 544000),
#     'modified_at': datetime.datetime(2019, 10, 27, 6, 47, 38, 341000),
#     'query': u'outdoor dog fence system',
#     'updates_succeeded': 15},
#    {'action_done': True,
#     'action_id': u'1-Ms9gKX4QUk4QXLKie28zAk',
#     'action_success': True,
#     'avg_state_var': 0.24765835277957604,
#     'created_at': datetime.datetime(2019, 10, 18, 7, 7, 49, 193000),
#     'modified_at': datetime.datetime(2019, 10, 27, 6, 47, 33, 976000),
#     'query': u'biotin',
#     'updates_succeeded': 8},
#    {'action_done': True,
#     'action_id': u'1-5Bji5g93CkHmnWfC5Lk7cL',
#     'action_success': True,
#     'avg_state_var': 0.15820991354748218,
#     'created_at': datetime.datetime(2019, 10, 9, 4, 25, 51, 459000),
#     'modified_at': datetime.datetime(2019, 10, 17, 20, 8, 9, 154000),
#     'query': u'bath toy organizer',
#     'updates_succeeded': 15},
#    {'action_done': True,
#     'action_id': u'1-rRNTwzXWpRCujJfERaMwUV',
#     'action_success': True,
#     'avg_state_var': 0.19323174865430218,
#     'created_at': datetime.datetime(2019, 10, 9, 4, 9, 44, 605000),
#     'modified_at': datetime.datetime(2019, 10, 17, 20, 7, 53, 437000),
#     'query': u'coloring book',
#     'updates_succeeded': 11},
#    {'action_done': True,
#     'action_id': u'1-sk5EF839ew9HhYofbC3Jd4',
#     'action_success': True,
#     'avg_state_var': None,
#     'created_at': datetime.datetime(2019, 10, 17, 15, 14, 10, 613000),
#     'modified_at': datetime.datetime(2019, 10, 17, 15, 16, 2, 369000),
#     'query': u'test',
#     'updates_succeeded': 1},
#    {'action_done': True,
#     'action_id': u'1-5oadruCSCuAtuMQtGuPg2S',
#     'action_success': True,
#     'avg_state_var': None,
#     'created_at': datetime.datetime(2019, 10, 17, 5, 22, 41, 979000),
#     'modified_at': datetime.datetime(2019, 10, 17, 5, 23, 21, 162000),
#     'query': u'b07dd9rqff',
#     'updates_succeeded': 1},
#    {'action_done': True,
#     'action_id': u'1-7GNeZ9Q7n5ZdJoMSCXTuYB',
#     'action_success': True,
#     'avg_state_var': None,
#     'created_at': datetime.datetime(2019, 10, 16, 3, 54, 0, 181000),
#     'modified_at': datetime.datetime(2019, 10, 17, 0, 42, 16, 163000),
#     'query': u'weather proof furniture',
#     'updates_succeeded': 2},
#    {'action_done': True,
#     'action_id': u'1-uVWSqRzzuLfNE9js96JB62',
#     'action_success': True,
#     'avg_state_var': None,
#     'created_at': datetime.datetime(2019, 10, 16, 3, 49, 20, 659000),
#     'modified_at': datetime.datetime(2019, 10, 16, 3, 50, 24, 796000),
#     'query': u'toys for little brothers',
#     'updates_succeeded': 1},
#    {'action_done': True,
#     'action_id': u'1-htsUKAvXKLG7kN9vYQ4BEe',
#     'action_success': True,
#     'avg_state_var': None,
#     'created_at': datetime.datetime(2019, 10, 15, 2, 8, 38, 226000),
#     'modified_at': datetime.datetime(2019, 10, 16, 2, 53, 20, 77000),
#     'query': u'emergency lantern',
#     'updates_succeeded': 3}]}}

# %%
reports_df['asin'].to_list()
# Out:
# [u'B07W1KDNRV',
#  u'B07TV1TRDR',
#  u'B0001ZWZ8O',
#  u'1945710799',
#  u'B07CWKGZYL',
#  u'B077YNNT54',
#  u'B07VH4GK85',
#  u'XYZ',
#  u'B07RFD9P55',
#  u'B0719B4LNH',
#  u'B07TT353XQ',
#  u'B000MVQBG4',
#  u'B013NNG18U',
#  u'B07DNHV7X9',
#  u'UNDEFINED',
#  u'B00IOZWC2M',
#  u'B07JK9DYNR',
#  u'B07MJ7N6VW',
#  u'B01DAPMQO4',
#  u'B07DD9RQFF',
#  u'B00T56FQAE',
#  u'UNDEFINED',
#  u'B07X9962NK',
#  u'0525568077',
#  u'0071774351',
#  u'1999896963',
#  u'B072NCYVQK',
#  u'B009SZXM4E',
#  u'B07GQV8H5V',
#  u'B07RMKR1GB',
#  u'B016MAVG86',
#  u'B00NPLSZF8',
#  u'B076ZVX8TM',
#  u'0692927999',
#  u'B07SZ4VP91',
#  u'B01C5QSENQ',
#  u'B07KT6BM9Y',
#  u'B073DXLPZ9',
#  u'B01M6ZFU02',
#  u'0071357807',
#  u'B00ZTNK8FA',
#  u'B07JJZTYSV',
#  u'B006SFUDT4',
#  u'B018L2WM86',
#  u'B073GJ59QM',
#  u'B07DD9RQFF',
#  u'B06W9NCZYX',
#  u'B07QH1YW88',
#  u'B07VC529JB',
#  u'B07RFL8J76']
